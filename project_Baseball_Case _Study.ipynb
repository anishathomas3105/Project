# %% [markdown]
# # Baseball Case Study
#
# Problem Statement:
#
# This dataset utilizes data from 2014 Major League Baseball seasons in order to develop an algorithm that predicts the number of wins for a given team in the 2015 season based on several different indicators of success. There are 16 different features that will be used as the inputs to the machine learning and the output will be a value that represents the number of wins.
#
# -- Input features: Runs, At Bats, Hits, Doubles, Triples, Homeruns, Walks, Strikeouts, Stolen Bases, Runs Allowed, Earned Runs, Earned Run Average (ERA), Shutouts, Saves, Complete Games and Errors
#
# -- Output: Number of predicted wins (W)
#
# To understand the columns meaning, follow the link given below to understand the baseball statistics: https://en.wikipedia.org/wiki/Baseball_statistics
#
# For downloading the dataset, use the link given below.
#
# Downlaod Files:
# https://github.com/dsrscientist/Data-Science-ML-Capstone-Projects/blob/master/baseball.csv

# %% [markdown]
# # Step 1 - ATTRIBUTES OF VARIABLES

# %% [markdown]
#     R(Runs)-It is counted when the batter reaches home plate, either by their own work (a home run) or     by the work of another batter
#
#     AB-At Bats - Indicate how many times an individual player came up to the plate, and had one of the     following things happen: a hit, a strikeout, reaching on an error, fielder’s choice.
#
#     H(Hits)-When the batter reaches at least first base in their at bat.
#
#     2B(Doubles)- A batter is credited with a double when he hits the ball into play and reaches second
#     base without the help of an intervening error or attempt to put out another baserunner
#
#     3B(Triples)-A triple occurs when a batter hits the ball into play and reaches third base without
#     the help of an intervening error or attempt to put out another baserunner.
#
#     HR(Homeruns)-A home run occurs when a batter hits a fair ball and scores on the play without being
#     put out or without the benefit of an error.
#
#     BB(Walks)-Reflects when a batter sees four balls and is rewarded first base as a result.
#
#     SO(Strikeouts)-Plate Appearances per Strikeout
#
#     SB(Stolen Bases)-Occurs when a runner advances to a base to which they are not entitled and the
#     official scorer rules that the advance should be credited to the action of the runner.
#
#     RA(Runs Allowed)-The amount of runs that score against a pitcher
#
#     ER(Earned Runs)- An earned run is any run that scores against a pitcher without the benefit of an
#     error or a passed ball
#
#     ERA(Earned Run Average)-The number of earned runs a pitcher allows per nine innings.
#
#     SHO(Shutouts) - A starting pitcher is credited with a shutout when he pitches the entire game for
#     a team and does not allow the opposition to score
#
#     SV(Saves)-A save is awarded to the relief pitcher who finishes a game for the winning team, under
#     certain circumstances
#
#     CG(Complete Games)- Is the act of a pitcher pitching an entire game without the benefit of a
#     relief pitcher
#
#     E(Errors)-error is an act, in the judgment of the official scorer, of a fielder misplaying a ball     in a manner that allows a batter or baserunner to advance one or more bases or allows a plate         appearance to continue after the batter should have been put out. The term error is sometimes used     to refer to the play during which an error was committed.
#
#     Target variable W- Number of predicted wins

# %% [markdown]
# # Importing necessary libraries, loading the Data Set, Data Descprtive Analysis and Observations.

# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Loading the dataset.

# %%
baseball=pd.read_csv('Baseball Case Study.csv')
baseball
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
#checking the first five rows
baseball.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
#checking the last five rows
baseball.tail()
# Out:
#      W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 25  92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26  84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27  79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28  74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29  68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV   E
# 25   21  47  75
# 26   18  41  78
# 27   12  44  86
# 28    6  41  92
# 29    4  36  95

# %%
#picking 2 random samples
baseball.sample(2)
# Out:
#      W    R    AB     H   2B  3B   HR   BB    SO  SB   RA   ER   ERA  CG  SHO  \
# 20  90  683  5527  1351  295  17  177  488  1290  51  613  557  3.43   1   14
# 13  76  656  5544  1379  262  22  198  478  1336  69  726  677  4.16   6   12
#
#     SV   E
# 20  50  88
# 13  45  94

# %% [markdown]
#  Data Descriptive Analysis

# %%
#checking the data shape
baseball.shape
# Out:
# (30, 17)

# %% [markdown]
# Observation:
#     There are 30 rows of data and 17 columns including the target variable.

# %%
#Checking the datatypes
baseball.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %% [markdown]
# Observation: Except ERA all other columns are integer data type.

# %%
#Checking data info
baseball.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
#Checking data description for all numerical columns
baseball.describe().T
# Out:
#      count         mean         std      min        25%       50%      75%  \
# W     30.0    80.966667   10.453455    63.00    74.0000    81.000    87.75
# R     30.0   688.233333   58.761754   573.00   651.2500   689.000   718.25
# AB    30.0  5516.266667   70.467372  5385.00  5464.0000  5510.000  5570.00
# H     30.0  1403.533333   57.140923  1324.00  1363.0000  1382.500  1451.50
# 2B    30.0   274.733333   18.095405   236.00   262.2500   275.500   288.75
# 3B    30.0    31.300000   10.452355    13.00    23.0000    31.000    39.00
# HR    30.0   163.633333   31.823309   100.00   140.2500   158.500   177.00
# BB    30.0   469.100000   57.053725   375.00   428.2500   473.000   501.25
# SO    30.0  1248.200000  103.759470   973.00  1157.5000  1261.500  1311.50
# SB    30.0    83.500000   22.815225    44.00    69.0000    83.500    96.50
# RA    30.0   688.233333   72.108005   525.00   636.2500   695.500   732.50
# ...

# %%
#The columns
baseball.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
baseball.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# Observations:
#     There are no null values in this dataset

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS(EDA) AND VISUALIZATION

# %%
#importing teh necessary libraries

import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.histplot(baseball['R'],kde=True)
# Out:
# <AxesSubplot:xlabel='R', ylabel='Count'>

# %% [markdown]
# Observations: There could be outliers present between 850-900

# %%
sns.histplot(baseball['AB'],kde=True)
# Out:
# <AxesSubplot:xlabel='AB', ylabel='Count'>

# %% [markdown]
# Observations: Seems to be a normal distribution with no outliers.

# %%
sns.histplot(baseball['H'],kde=True)
# Out:
# <AxesSubplot:xlabel='H', ylabel='Count'>

# %%
sns.histplot(baseball['2B'],kde=True)
# Out:
# <AxesSubplot:xlabel='2B', ylabel='Count'>

# %% [markdown]
# Observation: Data seems to be slightly left skewed.

# %%
sns.histplot(baseball['3B'],kde=True)
# Out:
# <AxesSubplot:xlabel='3B', ylabel='Count'>

# %%
sns.histplot(baseball['HR'],kde=True)
# Out:
# <AxesSubplot:xlabel='HR', ylabel='Count'>

# %%
sns.histplot(baseball['BB'],kde=True)
# Out:
# <AxesSubplot:xlabel='BB', ylabel='Count'>

# %%
sns.histplot(baseball['SO'],kde=True)
# Out:
# <AxesSubplot:xlabel='SO', ylabel='Count'>

# %%
sns.histplot(baseball['SB'],kde=True)
# Out:
# <AxesSubplot:xlabel='SB', ylabel='Count'>

# %%
sns.histplot(baseball['RA'],kde=True)
# Out:
# <AxesSubplot:xlabel='RA', ylabel='Count'>

# %%
sns.histplot(baseball['ER'],kde=True)
# Out:
# <AxesSubplot:xlabel='ER', ylabel='Count'>

# %%
sns.histplot(baseball['ERA'],kde=True)
# Out:
# <AxesSubplot:xlabel='ERA', ylabel='Count'>

# %%
sns.histplot(baseball['CG'],kde=True)
# Out:
# <AxesSubplot:xlabel='CG', ylabel='Count'>

# %% [markdown]
# Observation: The data is right-skewed.

# %%
sns.histplot(baseball['SHO'],kde=True)
# Out:
# <AxesSubplot:xlabel='SHO', ylabel='Count'>

# %% [markdown]
# Observation: Data is slightly right skewed.

# %%
sns.histplot(baseball['SV'],kde=True)
# Out:
# <AxesSubplot:xlabel='SV', ylabel='Count'>

# %%
sns.histplot(baseball['E'],kde=True)
# Out:
# <AxesSubplot:xlabel='E', ylabel='Count'>

# %% [markdown]
# Observations: The data is right skewed.

# %% [markdown]
# Most of the data dont fllow a normal distribution and are skewed.

# %% [markdown]
# Bivariate Analysis with scatterplot

# %%
sns.scatterplot(x = 'R', y ='W', data = baseball)
sns.regplot(x='R',y= 'W',data=baseball)
# Out:
# <AxesSubplot:xlabel='R', ylabel='W'>

# %% [markdown]
# Observation: Seems to be a positive corelation between W & R

# %%
sns.scatterplot(x = 'AB', y ='W', data = baseball)
sns.regplot(x='AB',y= 'W',data=baseball)
# Out:
# <AxesSubplot:xlabel='AB', ylabel='W'>

# %% [markdown]
# Observation: There seems to be  no coorelaton between Win and AB

# %%
sns.scatterplot(x = 'H', y ='W', data = baseball)
sns.regplot(x='H',y= 'W',data=baseball)
# Out:
# <AxesSubplot:xlabel='H', ylabel='W'>

# %% [markdown]
# Observation: There seems to be no coorelaton between Win and H

# %%
sns.scatterplot(x= '2B', y= 'W', data = baseball)
sns.regplot(x='2B',y= 'W',data=baseball)
# Out:
# <AxesSubplot:xlabel='2B', ylabel='W'>

# %% [markdown]
# Observation: There seems to be a positive relation between 2B & W

# %%
sns.scatterplot(x = '3B', y='W', data = baseball)
sns.regplot(x='3B',y= 'W',data=baseball)
# Out:
# <AxesSubplot:xlabel='3B', ylabel='W'>

# %% [markdown]
# Observation:  There seems to be a weak corelation or no corelation between 3B & W

# %%
sns.scatterplot(x='HR', y= 'W', data =baseball)
sns.regplot(x='HR',y= 'W',data=baseball)
# Out:
# <AxesSubplot:xlabel='HR', ylabel='W'>

# %% [markdown]
# Observation: Some correlation seems to be present here.

# %%
sns.scatterplot(x='BB', y = 'W', data = baseball)
sns.regplot(x='BB',y= 'W',data=baseball)
# Out:
# <AxesSubplot:xlabel='BB', ylabel='W'>

# %% [markdown]
# Observation: Positive weak Correlation seems to be there between W & BB

# %%
sns.scatterplot(x='SO', y= 'W', data= baseball)
sns.regplot(x='SO',y= 'W',data=baseball)
# Out:
# <AxesSubplot:xlabel='SO', ylabel='W'>

# %% [markdown]
# Observation: weak corelation between W & SO

# %%
sns.scatterplot(x='SB', y='W', data= baseball)
sns.regplot(x='SB',y= 'W',data=baseball)
# Out:
# <AxesSubplot:xlabel='SB', ylabel='W'>

# %% [markdown]
# Observation: There seems to be no corelation between W & SB

# %%
sns.scatterplot(x='RA', y='W', data=baseball)
sns.regplot(x='RA',y= 'W',data=baseball)
# Out:
# <AxesSubplot:xlabel='RA', ylabel='W'>

# %% [markdown]
# Observation: There seems to be a negative corelation between W & RA

# %%
sns.scatterplot(x='ER', y='W', data= baseball)
sns.regplot(x='ER',y= 'W',data=baseball)
# Out:
# <AxesSubplot:xlabel='ER', ylabel='W'>

# %% [markdown]
# Observation: There seems to be a negative correaltion between ER & W

# %%
sns.scatterplot(x='ERA', y='W', data =baseball)
sns.regplot(x='ERA',y= 'W',data=baseball)
# Out:
# <AxesSubplot:xlabel='ERA', ylabel='W'>

# %% [markdown]
# Observation: There seems to be a negative correaltion between ERA & W

# %%
sns.scatterplot(x='CG',y='W', data= baseball)
sns.regplot(x='CG',y= 'W',data=baseball)
# Out:
# <AxesSubplot:xlabel='CG', ylabel='W'>

# %% [markdown]
# Observation: There seens to be no correlation between W & CG

# %%
sns.scatterplot(x='SHO', y='W', data=baseball)
sns.regplot(x='SHO',y= 'W',data=baseball)
# Out:
# <AxesSubplot:xlabel='SHO', ylabel='W'>

# %% [markdown]
# Observation: There is a positve corelation between W & SHO

# %%
sns.scatterplot(x='SV', y='W', data=baseball)
sns.regplot(x='SV',y= 'W',data=baseball)
# Out:
# <AxesSubplot:xlabel='SV', ylabel='W'>

# %% [markdown]
# Observation:SV is positively correlated to W.

# %%
sns.scatterplot(x='E', y='W', data= baseball)
sns.regplot(x='E',y= 'W',data=baseball)
# Out:
# <AxesSubplot:xlabel='E', ylabel='W'>

# %% [markdown]
# Observation: No corelation between W & E

# %% [markdown]
# Observations on the Bivariate Analysis
#
#         -The number of runs, home runs, doubles, Saves, Shutouts, and Walks are highly positively
#         linearly correlated.
#
#         -Stolen Bases, Runs Allowed, Earned Runs are highly negative linearly correlated.
#
#         -The remaining features have less to no linear correlation with no of Wins

# %% [markdown]
# # Correlation Check(Collinearity and Multicollinearity)- Multivariate Analysis

# %% [markdown]
#  - Collinearity Between Feature and Label
#  - Multicolinearity between features
#
#     Visualizing the correlation between (Features vs Label) and (Features vs Features)

# %%
#checking for general correlation
baseball.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %%
#checking for correlation between each feature and Label
baseball.corr()['W'].sort_values()
# Out:
# ERA   -0.819600
# RA    -0.812952
# ER    -0.809435
# 3B    -0.251118
# SB    -0.157234
# E     -0.089485
# AB    -0.087947
# H      0.037612
# CG     0.080533
# SO     0.111850
# HR     0.307407
# 2B     0.427797
# R      0.430751
# SHO    0.471805
# BB     0.484342
# SV     0.666530
# W      1.000000
# Name: W, dtype: float64

# %%
#Plotting a bar chart to visualize correlation through the stand-alone bars
plt.figure(figsize=(15,8))
baseball.corr()['W'].sort_values(ascending=False).drop(['W']).plot(kind='bar', color='b')
plt.show()

# %% [markdown]
# Observation: Some of the features are negatively corelated (AB,E,SB,3B,ER,RA,ERA) with Label W

# %% [markdown]
# # Multicollinearity Check

# %% [markdown]
# Multicollinearity is a statistical concept where several independent variables in a model are correlated. Two variables are considered to be perfectly collinear if their correlation coefficient is +/- 1.0. Multicollinearity among independent variables will result in less reliable statistical inferences. As this will result in two variables explaining the same thing, meaning one of them is useless and therefore we have to drop one of them.

# %%
#Plotting a heatmap to show correlation through the brightness of the map-squares
plt.figure(figsize=(15,7))
sns.heatmap(baseball.corr(),annot=True, linewidth=0,linecolor='black',fmt='.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Observations:
#
#     -There is multicollinearity between RA & ER(0.99)
#
#     -Also there is a direct relationship between ER & ERA(1.00)
#
#     - RA, ER & ERA also have a negative contribution to W(0.81,0.81 & 0.82 respectively)
#
#     -Sv has the maximum contribution to W with 0.67 followed by SHO 0.47

# %% [markdown]
# # Outlier Check

# %%
sns.boxplot(baseball['R'])
# Out:
# <AxesSubplot:xlabel='R'>

# %%
sns.boxplot(baseball['AB'])
# Out:
# <AxesSubplot:xlabel='AB'>

# %%
sns.boxplot(baseball['H'])
# Out:
# <AxesSubplot:xlabel='H'>

# %%
sns.boxplot(baseball['2B'])
# Out:
# <AxesSubplot:xlabel='2B'>

# %%
sns.boxplot(baseball['3B'])
# Out:
# <AxesSubplot:xlabel='3B'>

# %%
sns.boxplot(baseball['HR'])
# Out:
# <AxesSubplot:xlabel='HR'>

# %%
sns.boxplot(baseball['BB'])
# Out:
# <AxesSubplot:xlabel='BB'>

# %%
sns.boxplot(baseball['SO'])
# Out:
# <AxesSubplot:xlabel='SO'>

# %%
sns.boxplot(baseball['SB'])
# Out:
# <AxesSubplot:xlabel='SB'>

# %%
sns.boxplot(baseball['RA'])
# Out:
# <AxesSubplot:xlabel='RA'>

# %%
sns.boxplot(baseball['ER'])
# Out:
# <AxesSubplot:xlabel='ER'>

# %%
sns.boxplot(baseball['ERA'])
# Out:
# <AxesSubplot:xlabel='ERA'>

# %%
sns.boxplot(baseball['CG'])
# Out:
# <AxesSubplot:xlabel='CG'>

# %%
sns.boxplot(baseball['SHO'])
# Out:
# <AxesSubplot:xlabel='SHO'>

# %%
sns.boxplot(baseball['SV'])
# Out:
# <AxesSubplot:xlabel='SV'>

# %%
sns.boxplot(baseball['E'])
# Out:
# <AxesSubplot:xlabel='E'>

# %% [markdown]
# Observations:
#     Outliers are present in Error, Saves, Shutouts, Earned Run Average & in Runs

# %% [markdown]
# We will try removing the outliers with Zscore

# %%
#importing the necessary library
import scipy.stats
from scipy.stats import zscore

# %%
zscore(baseball)
# Out:
#            W         R        AB         H        2B        3B        HR  \
# 0   1.365409  0.619078  0.847731  1.663685  1.420173  1.041193 -0.787299
# 1   0.197838  0.134432 -0.711094 -0.970681  0.127403  1.235809 -0.243967
# 2   0.003243 -0.332906 -1.115233 -0.151891  1.588795 -0.223808 -0.723377
# 3  -0.483244 -1.146419  0.241522 -0.401088 -0.828122 -0.418423 -0.883181
# 4  -0.677839  0.013270  1.280738  1.984081  0.801892  1.722347 -0.403770
# 5   1.170814  3.509647 -0.104884  1.361089  1.869832 -1.391501  2.185047
# 6   0.587028  1.311430  0.732263 -0.116292 -0.153633 -1.196885  1.545833
# 7   0.003243  0.428681 -0.451289 -0.596886 -1.615025 -1.099578  1.705636
# 8  -0.094054 -0.765626 -0.451289 -0.365489  0.183611  0.068115  0.107601
# 9  -0.288649  1.034489  1.785913  1.628086  1.082929  0.165423 -0.084163
# 10  0.684326  1.086415 -0.076017  0.275303  0.239818  0.068115  0.267405
# 11  0.489731  0.705622 -0.826562 -0.721484  0.183611 -0.515731  2.121125
# ...

# %%
z=np.abs(zscore(baseball))
z
# Out:
#            W         R        AB         H        2B        3B        HR  \
# 0   1.365409  0.619078  0.847731  1.663685  1.420173  1.041193  0.787299
# 1   0.197838  0.134432  0.711094  0.970681  0.127403  1.235809  0.243967
# 2   0.003243  0.332906  1.115233  0.151891  1.588795  0.223808  0.723377
# 3   0.483244  1.146419  0.241522  0.401088  0.828122  0.418423  0.883181
# 4   0.677839  0.013270  1.280738  1.984081  0.801892  1.722347  0.403770
# 5   1.170814  3.509647  0.104884  1.361089  1.869832  1.391501  2.185047
# 6   0.587028  1.311430  0.732263  0.116292  0.153633  1.196885  1.545833
# 7   0.003243  0.428681  0.451289  0.596886  1.615025  1.099578  1.705636
# 8   0.094054  0.765626  0.451289  0.365489  0.183611  0.068115  0.107601
# 9   0.288649  1.034489  1.785913  1.628086  1.082929  0.165423  0.084163
# 10  0.684326  1.086415  0.076017  0.275303  0.239818  0.068115  0.267405
# 11  0.489731  0.705622  0.826562  0.721484  0.183611  0.515731  2.121125
# ...

# %%
np.where(z>3)
# Out:
# (array([5], dtype=int64), array([1], dtype=int64))

# %%
z.iloc[5][1]
# Out:
# 3.5096470447193067

# %%
(len(np.where(z>3)))
# Out:
# 2

# %% [markdown]
# Observation: As the outlier is present in the target column we are not removing it. We are continuing with the orginal dataset.

# %%
#Checking for skewness in each independent variable.
baseball.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %% [markdown]
# # Observations on Skewness Check:
# Lets assume Skewness threshold is taken as +/-0.50.Meaning any value outside +/-0.50 contains skewness. Hence the below features are skewed:
#
# - R
# - H
# -CG
# -SHO
# -SV
# -E

# %%
#using Power transform to reduce skewness
from sklearn.preprocessing import PowerTransformer
scaler = PowerTransformer(method ='yeo-johnson')

# %%
#extracting the columns that are skewed
data=['R','CG','SHO','SV','E']

# %%
#Now removing skewness by Power Transformation and updating dataset(baseball_new) with result
baseball[data] = scaler.fit_transform(baseball[data].values)

# %%
baseball.skew()
# Out:
# W      0.047089
# R     -0.055006
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG    -0.059785
# SHO    0.006560
# SV     0.000836
# E      0.063909
# dtype: float64

# %% [markdown]
# # DATA PREPROCESSING

# %% [markdown]
#  Removal of Duplicates and Unwanted Column

# %%
baseball.drop_duplicates(inplace=True)

# %%
baseball.shape
# Out:
# (30, 17)

# %% [markdown]
# Observation: There are no duplicates in the dataset

# %% [markdown]
# Dropping of Features that strongly promotes multicollinearity(VIF)

# %% [markdown]
# To solve this multicollinearity problem, we have to first scale our data using Standard Scaler

# %%
#importing the required library
from sklearn.preprocessing import StandardScaler

# %%
x=baseball.iloc[:,1:]
x.shape
# Out:
# (30, 16)

# %%
x
# Out:
#            R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  \
# 0   0.728218  5575  1497  300  42  139  383   973  104  641  601  3.73
# 1   0.261212  5467  1349  277  44  156  439  1264   70  700  653  4.07
# 2  -0.244821  5439  1395  303  29  141  533  1157   86  640  584  3.67
# 3  -1.285129  5533  1381  260  27  136  404  1231   68  701  643  3.98
# 4   0.135622  5605  1515  289  49  151  455  1259   83  803  746  4.64
# 5   2.671903  5509  1480  308  17  232  570  1151   88  670  609  3.80
# 6   1.309688  5567  1397  272  19  212  554  1227   63  698  652  4.03
# 7   0.551199  5485  1370  246  20  217  418  1331   44  693  646  4.05
# 8  -0.770266  5485  1383  278  32  167  436  1310   87  642  604  3.74
# 9   1.088096  5640  1495  294  33  161  478  1148   71  753  694  4.31
# 10  1.130709  5511  1419  279  32  172  503  1233  101  733  680  4.24
# 11  0.806086  5459  1363  278  26  230  486  1392  121  618  572  3.57
# ...

# %%
y=baseball.iloc[:,0]

# %%
y.shape
# Out:
# (30,)

# %%
ss=StandardScaler()
x_scaled=ss.fit_transform(x)
x_scaled
# Out:
# array([[ 0.72821774,  0.84773126,  1.66368512,  1.42017307,  1.04119304,
#         -0.7872986 , -1.53490242, -2.69762957,  0.91388329, -0.66623393,
#         -0.50511008, -0.50695519, -0.35984364, -0.78957937,  1.546378  ,
#         -0.3349525 ],
#        [ 0.26121202, -0.71109353, -0.97068076,  0.12740339,  1.23580856,
#         -0.24396668, -0.5365919 ,  0.15487844, -0.60182558,  0.16597077,
#          0.24892985,  0.25459752, -0.35984364,  0.25177537,  0.36044386,
#         -0.53221128],
#        [-0.24482102, -1.1152333 , -0.15189137,  1.58879521, -0.22380785,
#         -0.7233772 ,  1.13914361, -0.89398189,  0.11144918, -0.68033909,
#         -0.75162313, -0.64134684,  1.99351257, -0.24539345, -0.6075936 ,
#         -1.34233137],
#        [-1.28512888,  0.24152162, -0.40108814, -0.82812203, -0.41842337,
#         -0.8831807 , -1.16053598, -0.16860185, -0.69098493,  0.18007593,
#          0.10392217,  0.05301004,  1.22010317, -0.51075929, -0.76445333,
#          0.67852361],
# ...

# %%
x_scaled.shape
# Out:
# (30, 16)

# %%
x_scaled.std()
# Out:
# 1.0

# %%
baseball.skew()
# Out:
# W      0.047089
# R     -0.055006
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG    -0.059785
# SHO    0.006560
# SV     0.000836
# E      0.063909
# dtype: float64

# %%
#for vif

import statsmodels.api as sm
from scipy import stats
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif=pd.DataFrame()

# %%
vif['vif']=[variance_inflation_factor(x_scaled,i) for i in range(x_scaled.shape[1])]

# %%
vif['Features']=x.columns

# %%
vif
# Out:
#             vif Features
# 0      9.532572        R
# 1     13.371617       AB
# 2      7.683353        H
# 3      3.653087       2B
# 4      3.579517       3B
# 5      9.670640       HR
# 6      3.554694       BB
# 7      2.535725       SO
# 8      1.993525       SB
# 9    191.373694       RA
# 10  1822.756717       ER
# 11  1315.241456      ERA
# 12     2.659324       CG
# 13     3.278037      SHO
# 14     5.030380       SV
# 15     2.192627        E

# %% [markdown]
# Observation: As the VIF is high for ER & ERA and also in the coorelation heatmap we had seen that Er, RA & ERA are bringing the maximum negative correlation to the label column we can drop the 2 columns.

# %%
#dropping ERA column
baseball.drop('ERA',axis=1,inplace=True)

# %%
#dropping ER column
baseball.drop('ER',axis=1,inplace=True)

# %%
baseball.shape
# Out:
# (30, 15)

# %%
baseball
# Out:
#       W         R    AB     H   2B  3B   HR   BB    SO   SB   RA        CG  \
# 0    95  0.728218  5575  1497  300  42  139  383   973  104  641 -0.359844
# 1    83  0.261212  5467  1349  277  44  156  439  1264   70  700 -0.359844
# 2    81 -0.244821  5439  1395  303  29  141  533  1157   86  640  1.993513
# 3    76 -1.285129  5533  1381  260  27  136  404  1231   68  701  1.220103
# 4    74  0.135622  5605  1515  289  49  151  455  1259   83  803  1.220103
# 5    93  2.671903  5509  1480  308  17  232  570  1151   88  670  1.220103
# 6    87  1.309688  5567  1397  272  19  212  554  1227   63  698  0.064630
# 7    81  0.551199  5485  1370  246  20  217  418  1331   44  693 -1.729889
# 8    80 -0.770266  5485  1383  278  32  167  436  1310   87  642 -0.909181
# 9    78  1.088096  5640  1495  294  33  161  478  1148   71  753  0.064630
# 10   88  1.130709  5511  1419  279  32  172  503  1233  101  733  0.716445
# ...

# %% [markdown]
# # Transforming data into standard normal distribution

# %%
round(x_scaled.mean(),2)
# Out:
# 0.0

# %%
x_scaled.std()
# Out:
# 1.0

# %% [markdown]
# MODEL BUILDING

# %% [markdown]
# Model 1-Linear Regression

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.model_selection import cross_val_score

# %%
x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.20)

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_train,y_train)
# Out:
# 0.9578559174300023

# %%
predict_y=lr.predict(x_test)

# %%
predict_y
# Out:
# array([85.28967647, 81.09920861, 73.93860375, 66.23534778, 85.87020169,
#        97.52247661])

# %%
lr.coef_
# Out:
# array([ 5.07953316e+00, -6.30933366e+00,  3.98245099e+00,  6.91938400e-04,
#        -5.60482731e-02, -1.87577222e-01, -8.37690893e-01, -1.39616909e+00,
#        -1.25553035e+00,  2.48839427e+00,  4.35302016e+01, -5.21405417e+01,
#        -1.22498422e-01, -1.81818843e-01,  2.10173895e+00,  8.31373345e-01])

# %%
lr.intercept_
# Out:
# 80.9985171635214

# %%
print("Mean Absolute Error:", mean_absolute_error(y_test,predict_y))
print("Mean Squared Error:", mean_squared_error(y_test,predict_y))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test,predict_y)))
linear_score=r2_score(y_test,predict_y)
print("The Test accuracy score of Linear Regression Model:", linear_score)
# Out:
# Mean Absolute Error: 4.457402659693464
# Mean Squared Error: 32.065870569175935
# Root Mean Squared Error: 5.662673447160443
# The Test accuracy score of Linear Regression Model: 0.7473470473866637

# %% [markdown]
# Checking for overfitting in Linear Regression model.

# %%
score=cross_val_score(lr,x_scaled,y,cv=4)
print(score)
cv_li=score.mean()
print(round(score.std()),2)
print("The cv score for Linear Regression:",cv_li)
# Out:
# [ 0.63636344 -2.24926624  0.79487934  0.248782  ]
# 1 2
# The cv score for Linear Regression: -0.1423103650233861

# %% [markdown]
# Difference between Accuracy Score and Cross Validation Score

# %%
#test accuracy score of linear regression
linear_score
# Out:
# 0.7473470473866637

# %%
#CV score for linear regression
cv_linear=score.mean()
cv_linear
# Out:
# -0.1423103650233861

# %%
lr_Acc_vs_CV_Score=np.abs(linear_score-cv_linear)
print("Difference between Accuracy and Cross Validation Score = ",lr_Acc_vs_CV_Score)
# Out:
# Difference between Accuracy and Cross Validation Score =  0.8896574124100498

# %% [markdown]
# KNeighborsRegressor Model

# %%
#Using KNeighbors Regressor 
from sklearn.neighbors import KNeighborsRegressor
knn=KNeighborsRegressor()

# %%
knn.fit(x_train,y_train)
# Out:
# KNeighborsRegressor()

# %%
x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.20)

# %%
knn.score(x_train,y_train)
# Out:
# 0.6483130395927422

# %%
predict_x=knn.predict(x_test)
predict_x
# Out:
# array([75.2, 89.4, 71.2, 77.8, 85.4, 79.4])

# %%
knn_acc_test=r2_score(y_test,predict_x)
print("Accuracy test score for KNN:", knn_acc_test)                
print("Mean Absolute error:",mean_absolute_error(y_test,predict_x))
print("Mean Squared error:", mean_squared_error(y_test,predict_x))
print('Root Mean Squared error:',np.sqrt(mean_squared_error(y_test,predict_x)))
# Out:
# Accuracy test score for KNN: 0.7641577060931901
# Mean Absolute error: 3.866666666666667
# Mean Squared error: 21.933333333333323
# Root Mean Squared error: 4.683303677248927

# %% [markdown]
# Checking Cross Validation score

# %%
scr=cross_val_score(knn,x_scaled,y,cv=5)
print(scr)
print(scr.std())
cv_knn=scr.mean()
print('The CV score of Knn:',cv_knn)
# Out:
# [ 0.2401421  -1.66335878  0.28927647  0.27118367  0.50480473]
# 0.8013556053195526
# The CV score of Knn: -0.07159036188117218

# %%
knn_acc_test_vs_CV_Score=np.abs(knn_acc_test-cv_knn)
print("Difference between Accuracy and Cross Validation Score of Knn = ",knn_acc_test_vs_CV_Score)
# Out:
# Difference between Accuracy and Cross Validation Score of Knn =  0.8357480679743623

# %% [markdown]
# SGDRegressor Model

# %%
from sklearn.linear_model import SGDRegressor
sgd=SGDRegressor(alpha=0.01)

# %%
x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.20)

# %%
sgd.fit(x_train,y_train)
# Out:
# SGDRegressor(alpha=0.01)

# %%
sgd.score(x_train,y_train)
# Out:
# 0.9441064060555895

# %%
predict_y=sgd.predict(x_test)

# %%
score_test=sgd.score(x_test,y_test)

# %%
sgd_acc_test=r2_score(y_test,predict_y)
print("Accuracy test score for sgd:", sgd_acc_test)                
print("Mean Absolute error:",mean_absolute_error(y_test,predict_y))
print("Mean Squared error:", mean_squared_error(y_test,predict_y))
print('Root Mean Squared error:',np.sqrt(mean_squared_error(y_test,predict_y)))
# Out:
# Accuracy test score for sgd: 0.5600799308672446
# Mean Absolute error: 4.842093628458919
# Mean Squared error: 34.02048534626642
# Root Mean Squared error: 5.83270823428246

# %% [markdown]
# Checking Cross Validation score of SGDRegressor

# %%
sgd_sc=cross_val_score(sgd,x_scaled,y,cv=5)
print(sgd_sc)
print(sgd_sc.std())
cv_sgd=sgd_sc.mean()
print('The CV score of SGD:',cv_sgd)
# Out:
# [ 0.50123808 -1.19373739  0.55876916  0.6836786   0.75547255]
# 0.7329122653444793
# The CV score of SGD: 0.2610841989620775

# %%
#test accuracy score of SGD regression
sgd_acc_test
# Out:
# 0.5600799308672446

# %%
#CV score for SGD regression
cv_sgd
# Out:
# 0.2610841989620775

# %%
sgd_acc_test_vscv_sgd=np.abs(sgd_acc_test-cv_sgd)
print("Difference between Accuracy and Cross Validation Score of SGD Regressor= ",sgd_acc_test_vscv_sgd)
# Out:
# Difference between Accuracy and Cross Validation Score of SGD Regressor=  0.2989957319051671

# %% [markdown]
# Support Vector Regressor(SVR) Model

# %%
from sklearn.svm import SVR

# %%
svr=SVR()

# %%
x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.20)

# %%
svr.fit(x_train,y_train)
# Out:
# SVR()

# %%
svr.score(x_train,y_train)
# Out:
# 0.25055209022625724

# %%
predict_y=svr.predict(x_test)

# %%
print("The absolute error is:",mean_absolute_error(y_test,predict_y))
print("The Mean Squared Error is:",mean_squared_error(y_test,predict_y))
print("The root mean squared error is:", np.sqrt(mean_squared_error(y_test,predict_y)))
svr_acc_test=r2_score(y_test,predict_y)
print("The test score is:",r2_score(y_test,predict_y))
# Out:
# The absolute error is: 11.58663566464248
# The Mean Squared Error is: 160.68208496445814
# The root mean squared error is: 12.676043742605899
# The test score is: 0.06155823187532561

# %% [markdown]
# Checking Cross Validation score of SVR

# %%
svr_sc=cross_val_score(svr, x,y,cv=5)

print(svr_sc)
print(svr_sc.std())
cv_svr=svr_sc.mean()
print('The CV score of SGD:',cv_svr)
# Out:
# [-0.16049743 -0.76311365 -0.31860808 -0.75229838 -0.29902395]
# 0.25016579897668145
# The CV score of SGD: -0.45870829680123537

# %%
#Difference between Accuracy Score and Cross Validation Score
svr_acc_test_vscv_svr=np.abs(svr_acc_test-cv_svr)
print("Difference between Accuracy and Cross Validation Score of SGD Regressor= ",svr_acc_test_vscv_svr)
# Out:
# Difference between Accuracy and Cross Validation Score of SGD Regressor=  0.520266528676561

# %% [markdown]
# Decision tree Regressor Model

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dtr=DecisionTreeRegressor()

# %%
dtr.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
dtr.score(x_train,y_train)
# Out:
# 1.0

# %%
predict_y=dtr.predict(x_test)

# %%
print("The absolute error is:",mean_absolute_error(y_test,predict_y))
print("The Mean Squared Error is:",mean_squared_error(y_test,predict_y))
print("The root mean squared error is:", np.sqrt(mean_squared_error(y_test,predict_y)))
dtr_acc_test=r2_score(y_test,predict_y)
print("The test score is:",r2_score(y_test,predict_y))
# Out:
# The absolute error is: 7.333333333333333
# The Mean Squared Error is: 90.33333333333333
# The root mean squared error is: 9.504384952922168
# The test score is: 0.472420506164828

# %% [markdown]
# Checking Cross Validation score of DecisionTreeRegressor

# %%
dtr_sc=cross_val_score(dtr, x,y,cv=5)

print(dtr_sc)
print(dtr_sc.std())
cv_dtr=dtr_sc.mean()
print('The CV score of Decision Tree Regressor is:',cv_dtr)
# Out:
# [-0.9955595  -7.63358779 -0.5102818  -0.13594976  0.11952663]
# 2.925407038055318
# The CV score of Decision Tree Regressor is: -1.8311704447273214

# %%
#Difference between Accuracy Score and Cross Validation Score
dtr_acc_test_vs_cv_dtr=np.abs(dtr_acc_test-cv_dtr)
print("Difference between Accuracy and Cross Validation Score of SGD Regressor= ",dtr_acc_test_vs_cv_dtr)
# Out:
# Difference between Accuracy and Cross Validation Score of SGD Regressor=  2.3035909508921493

# %% [markdown]
# COMPARING ALL MACHINE LEARNING MODELS

# %% [markdown]
# Creating a dataframe that will show the metrics of all the models.

# %%
#Constructing a dataframe...
models = pd.DataFrame({'ML_Model' : ['Linear Regression','KNeigbors Regressor','SGDREgressor','SVR','Decision Tree Regressor'],'Accuracy_Score' : [linear_score,knn_acc_test,sgd_acc_test,svr_acc_test,dtr_acc_test],'Cross_Validation_Score':[cv_linear,cv_knn,cv_sgd,cv_svr,cv_dtr],'Accuracy_VS_CVScore':[lr_Acc_vs_CV_Score,knn_acc_test_vs_CV_Score,sgd_acc_test_vscv_sgd,svr_acc_test_vscv_svr,dtr_acc_test_vs_cv_dtr] })
models
# Out:
#                   ML_Model  Accuracy_Score  Cross_Validation_Score  \
# 0        Linear Regression        0.747347               -0.142310
# 1      KNeigbors Regressor        0.764158               -0.071590
# 2             SGDREgressor        0.560080                0.261084
# 3                      SVR        0.061558               -0.458708
# 4  Decision Tree Regressor        0.472421               -1.831170
#
#    Accuracy_VS_CVScore
# 0             0.889657
# 1             0.835748
# 2             0.298996
# 3             0.520267
# 4             2.303591

# %%
#Plotting the accuracy score

plt.figure(figsize = (10, 5))
sns.set_style('darkgrid')

sns.barplot(x = 'Accuracy_Score', y = 'ML_Model', data = models)

plt.xlabel('Accuracy Score in %', fontsize = 15)
plt.ylabel('ML Model', fontsize = 15)

plt.title('ML Model Comparison', fontsize = 16)

plt.show()

# %% [markdown]
# We are selecting SGDRegressor as it has the least difference between accuracy & cv score.

# %% [markdown]
# HYPERPARAMETER TUNNING

# %%
from sklearn.model_selection import GridSearchCV

# %%
sgd=SGDRegressor()

# %%
penalty = ['l1', 'l2'] 
parameter={'alpha':[.0001,.001,.01,.1]}

# %%
#Gridsearch for hyperparameter tunning
gridsearch = GridSearchCV(sgd, parameter, cv=5)
gridsearch.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=SGDRegressor(alpha=0.1),
#              param_grid={'alpha': [0.0001, 0.001, 0.01, 0.1]})

# %%
sgd.fit(x_train,y_train)
# Out:
# SGDRegressor(alpha=0.1)

# %%
sgd.score(x_train,y_train)
# Out:
# 0.9359812576192145

# %%
pred_x=sgd.predict(x_test)

# %%
print(r2_score(pred_x,y_test))
# Out:
# -0.25008613525295775

# %%
#to know with which alpha value we get the best score
print(gridsearch.best_score_)
print(gridsearch.best_params_)
# Out:
# 0.4575791295755063
# {'alpha': 0.1}

# %%
#using the best parameter which we found using grid search CV

sgd=SGDRegressor(alpha=0.1)
sgd.fit(x_train,y_train)
predict_y=sgd.predict(x_test)
sgd_acc_test=r2_score(y_test,predict_y)
print("Accuracy test score for sgd:", sgd_acc_test)                
print("Mean Absolute error:",mean_absolute_error(y_test,predict_y))
print("Mean Squared error:", mean_squared_error(y_test,predict_y))
print('Root Mean Squared error:',np.sqrt(mean_squared_error(y_test,predict_y)))
sgd.intercept_
# Out:
# Accuracy test score for sgd: 0.6836776387610763
# Mean Absolute error: 4.409253402665129
# Mean Squared error: 24.46226260247676
# Root Mean Squared error: 4.945933946432843
# array([80.55311678])

# %% [markdown]
# We have got the best score with SGDRegressor(alpha=0.1). We will be saving this model.

# %% [markdown]
#  MODEL SAVING

# %%
import pickle

# %%
filename='Machine_Model_Project_Baseball'
pickle.dump(sgd,open(filename,'wb'))
