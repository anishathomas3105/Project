# %% [markdown]
# # Problem Statement:
# Avocado is a fruit consumed by people heavily in the United States.
#
# Content
# This data was downloaded from the Hass Avocado Board website in May of 2018 & compiled into a single CSV.
#
# The table below represents weekly 2018 retail scan data for National retail volume (units) and price. Retail scan data comes directly from retailers’ cash registers based on actual retail sales of Hass avocados.
#
# Starting in 2013, the table below reflects an expanded, multi-outlet retail data set. Multi-outlet reporting includes an aggregation of the following channels: grocery, mass, club, drug, dollar and military. The Average Price (of avocados) in the table reflects a per unit (per avocado) cost, even when multiple units (avocados) are sold in bags.
#
# The Product Lookup codes (PLU’s) in the table are only for Hass avocados. Other varieties of avocados (e.g. greenskins) are not included in this table.
#
# Some relevant columns in the dataset:
#
# Date - The date of the observation
#
# AveragePrice - the average price of a single avocado
#
# type - conventional or organic
#
# year - the year
#
# Region - the city or region of the observation
#
# Total Volume - Total number of avocados sold
#
# 4046 - Total number of avocados with PLU 4046 sold
#
# 4225 - Total number of avocados with PLU 4225 sold
#
# 4770 - Total number of avocados with PLU 4770 sold
#
#
# Inspiration /Label
#
# The dataset can be seen in two angles to find the region and find the average price .
#
# Task: One of Classification and other of Regression
#
# Do both tasks in the same .ipynb file and submit at single file.
#
# To download the dataset, use the link given below.
#
# Downlaod Files:
# https://github.com/dsrscientist/Data-Science-ML-Capstone-Projects/blob/master/avocado.csv.zip

# %% [markdown]
# IMPORTING NECESSARY LIBRARIES, LOAD DATA SET, DATA DESCRIPTIVE ANALYSIS AND OBSERVATIONS

# %%
https://www.kaggle.com/code/sudeepraj/avocado-data-analysis
    https://www.kaggle.com/code/tekdogan/eda-for-avocado-prices/notebook
# Out:
#   File "C:\Users\User\AppData\Local\Temp/ipykernel_8292/3464962244.py", line 1
#     https://www.kaggle.com/code/sudeepraj/avocado-data-analysis
#           ^
# SyntaxError: invalid syntax

# %%
import numpy as np
import pandas as pd

import warnings
warnings.filterwarnings('ignore')

# %%
#loading the dataset
ava=pd.read_csv('avocado.csv',sep='\t')
#dropping the unnamed column as we already have an index column 
ava.drop('Unnamed: 0', axis=1, inplace = True)
ava
# Out:
#              Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0      27-12-2015          1.33      64236.62  1036.74   54454.85   48.16
# 1      20-12-2015          1.35      54876.98   674.28   44638.81   58.33
# 2      13-12-2015          0.93     118220.22   794.70  109149.67  130.50
# 3      06-12-2015          1.08      78992.15  1132.00   71976.41   72.58
# 4      29-11-2015          1.28      51039.60   941.48   43838.39   75.78
# ...           ...           ...           ...      ...        ...     ...
# 18244  04-02-2018          1.63      17074.83  2046.96    1529.20    0.00
# 18245  28-01-2018          1.71      13888.04  1191.70    3431.50    0.00
# 18246  21-01-2018          1.87      13766.76  1191.92    2452.79  727.94
# 18247  14-01-2018          1.93      16205.22  1527.63    2981.04  727.01
# 18248  07-01-2018          1.62      17489.58  2894.77    2356.13  224.53
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# ...

# %%
#checking the first five rows
ava.head()
# Out:
#          Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0  27-12-2015          1.33      64236.62  1036.74   54454.85   48.16
# 1  20-12-2015          1.35      54876.98   674.28   44638.81   58.33
# 2  13-12-2015          0.93     118220.22   794.70  109149.67  130.50
# 3  06-12-2015          1.08      78992.15  1132.00   71976.41   72.58
# 4  29-11-2015          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  2015  Albany
# 2     8145.35     8042.21      103.14          0.0  conventional  2015  Albany
# 3     5811.16     5677.40      133.76          0.0  conventional  2015  Albany
# 4     6183.95     5986.26      197.69          0.0  conventional  2015  Albany

# %%
#checking the last five rows
ava.tail()
# Out:
#              Date  AveragePrice  Total Volume     4046     4225    4770  \
# 18244  04-02-2018          1.63      17074.83  2046.96  1529.20    0.00
# 18245  28-01-2018          1.71      13888.04  1191.70  3431.50    0.00
# 18246  21-01-2018          1.87      13766.76  1191.92  2452.79  727.94
# 18247  14-01-2018          1.93      16205.22  1527.63  2981.04  727.01
# 18248  07-01-2018          1.62      17489.58  2894.77  2356.13  224.53
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 18244    13498.67    13066.82      431.85          0.0  organic  2018
# 18245     9264.84     8940.04      324.80          0.0  organic  2018
# 18246     9394.11     9351.80       42.31          0.0  organic  2018
# 18247    10969.54    10919.54       50.00          0.0  organic  2018
# 18248    12014.15    11988.14       26.01          0.0  organic  2018
#
#                  region
# 18244  WestTexNewMexico
# 18245  WestTexNewMexico
# 18246  WestTexNewMexico
# ...

# %%
#picking 4 random samples
ava.sample(4)
# Out:
#              Date  AveragePrice  Total Volume     4046      4225     4770  \
# 16161  12-03-2017          0.61      11558.79   523.31   1918.64     0.00
# 9259   07-06-2015          1.71      13808.71  5560.86   3115.87  1042.17
# 3072   27-11-2016          1.57      73261.05  1006.16  50581.93    12.21
# 26     28-06-2015          1.37      89534.81   664.23  57545.79  4662.71
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# 16161     9116.84       66.66     9050.18         0.00       organic  2017
# 9259      4089.81     4076.52       13.29         0.00       organic  2015
# 3072     21660.75    21641.31        0.00        19.44  conventional  2016
# 26       26662.08    26311.76      350.32         0.00  conventional  2015
#
#                     region
# 16161            Nashville
# 9259   BaltimoreWashington
# 3072      BuffaloRochester
# 26                  Albany

# %% [markdown]
# # Data Descriptive Analysis

# %%
#checking the data shape
ava.shape
# Out:
# (18249, 13)

# %%
#checking for nature of datatypes
ava.dtypes
# Out:
# Date             object
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year              int64
# region           object
# dtype: object

# %%
#Checking data info
ava.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          18249 non-null  object
#  1   AveragePrice  18249 non-null  float64
#  2   Total Volume  18249 non-null  float64
#  3   4046          18249 non-null  float64
#  4   4225          18249 non-null  float64
#  5   4770          18249 non-null  float64
#  6   Total Bags    18249 non-null  float64
#  7   Small Bags    18249 non-null  float64
#  8   Large Bags    18249 non-null  float64
#  9   XLarge Bags   18249 non-null  float64
#  10  type          18249 non-null  object
#  11  year          18249 non-null  int64
#  12  region        18249 non-null  object
# dtypes: float64(9), int64(1), object(3)
# memory usage: 1.8+ MB

# %%
#Checking data description for all numerical columns
ava.describe().T
# Out:
#                 count           mean           std      min       25%  \
# AveragePrice  18249.0       1.405978  4.026766e-01     0.44      1.10
# Total Volume  18249.0  850644.013009  3.453545e+06    84.56  10838.58
# 4046          18249.0  293008.424531  1.264989e+06     0.00    854.07
# 4225          18249.0  295154.568356  1.204120e+06     0.00   3008.78
# 4770          18249.0   22839.735993  1.074641e+05     0.00      0.00
# Total Bags    18249.0  239639.202060  9.862424e+05     0.00   5088.64
# Small Bags    18249.0  182194.686696  7.461785e+05     0.00   2849.42
# Large Bags    18249.0   54338.088145  2.439660e+05     0.00    127.47
# XLarge Bags   18249.0    3106.426507  1.769289e+04     0.00      0.00
# year          18249.0    2016.147899  9.399385e-01  2015.00   2015.00
#
#                     50%        75%          max
# AveragePrice       1.37       1.66         3.25
# Total Volume  107376.76  432962.29  62505646.52
# 4046            8645.30  111020.20  22743616.17
# ...

# %%
#Checking data description for all non-numerical columns. 
#Assigning all non numeric columns to ava_non

ava_non=ava[['Date','type','region']]
ava_non.describe().T
# Out:
#         count unique           top  freq
# Date    18249    169    27-12-2015   108
# type    18249      2  conventional  9126
# region  18249     54        Albany   338

# %%
#lets check the columns
ava.columns
# Out:
# Index(['Date', 'AveragePrice', 'Total Volume', '4046', '4225', '4770',
#        'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type', 'year',
#        'region'],
#       dtype='object')

# %%
#Checking for null values
ava.isnull().sum()
# Out:
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
#importing libraries for visualisation
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.heatmap(ava.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# Observation: No null values in this dataset.

# %%
#Checking the content of each Categorical columns
ava['region'].value_counts()
# Out:
# Albany                 338
# Sacramento             338
# Northeast              338
# NorthernNewEngland     338
# Orlando                338
# Philadelphia           338
# PhoenixTucson          338
# Pittsburgh             338
# Plains                 338
# Portland               338
# RaleighGreensboro      338
# RichmondNorfolk        338
# Roanoke                338
# SanDiego               338
# Atlanta                338
# SanFrancisco           338
# Seattle                338
# SouthCarolina          338
# SouthCentral           338
# Southeast              338
# Spokane                338
# StLouis                338
# Syracuse               338
# Tampa                  338
# TotalUS                338
# West                   338
# NewYork                338
# NewOrleansMobile       338
# Nashville              338
# Midsouth               338
# BaltimoreWashington    338
# Boise                  338
# Boston                 338
# BuffaloRochester       338
# ...

# %%
#the regions from where the data was collected
ava['region'].nunique()
# Out:
# 54

# %%
ava.dtypes
# Out:
# Date             object
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year              int64
# region           object
# dtype: object

# %%
ava['type'].nunique()
# Out:
# 2

# %%
ava['type'].value_counts()
# Out:
# conventional    9126
# organic         9123
# Name: type, dtype: int64

# %% [markdown]
# Observations
#
# -The dataset is made of 18249 rows and 13 columns.
# - Here there will be 2 label columns taken 1 at a time. The label columns are Average Price & region.
# -There are no nullvalues in teh dataset.
# -There are 3 object type - Date, Type & region & 9 float type columns & 1 integer columns-year.
#
# About the 1st Target/Label:
# Average Price : This is one target variable and has the following properties:
# It has no null values
# Its Datatype is a floating type
# It is made up of Continuous data
# Since the target is made up of a continuous data hence this is a Regression Problem.
#
# About the 2nd Target/Label:
# Region : This is the other target variable and has the following properties:
# It has no null values
# Its Datatype is a object type
# It is made up of string data
# Since the target is made up of a object data hence this is a Classification Problem.

# %% [markdown]
# EXPLORATORY DATA ANALYSIS(EDA) AND VISUALIZATION

# %% [markdown]
# Count Distribution of Categorical Data - Univariate Analysis

# %%
#date is in string format we need to change that
print(ava['Date'].nunique())
sorted(ava['Date'].unique())
# Out:
# 169
# ['01-01-2017',
#  '01-02-2015',
#  '01-03-2015',
#  '01-05-2016',
#  '01-10-2017',
#  '01-11-2015',
#  '02-04-2017',
#  '02-07-2017',
#  '02-08-2015',
#  '02-10-2016',
#  '03-01-2016',
#  '03-04-2016',
#  '03-05-2015',
#  '03-07-2016',
#  '03-09-2017',
#  '03-12-2017',
#  '04-01-2015',
#  '04-02-2018',
#  '04-03-2018',
#  '04-06-2017',
#  '04-09-2016',
#  '04-10-2015',
#  '04-12-2016',
#  '05-02-2017',
#  '05-03-2017',
#  '05-04-2015',
#  '05-06-2016',
#  '05-07-2015',
#  '05-11-2017',
#  '06-03-2016',
#  '06-08-2017',
#  '06-09-2015',
#  '06-11-2016',
#  '06-12-2015',
#  '07-01-2018',
#  '07-02-2016',
#  '07-05-2017',
#  '07-06-2015',
#  '07-08-2016',
#  '08-01-2017',
#  '08-02-2015',
#  '08-03-2015',
#  '08-05-2016',
#  '08-10-2017',
#  '08-11-2015',
#  '09-04-2017',
#  '09-07-2017',
#  '09-08-2015',
#  '09-10-2016',
#  '10-01-2016',
#  '10-04-2016',
#  '10-05-2015',
#  '10-07-2016',
#  '10-09-2017',
#  '10-12-2017',
#  '11-01-2015',
#  '11-02-2018',
#  '11-03-2018',
# ...

# %%
ava.dtypes
# Out:
# Date             object
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year              int64
# region           object
# dtype: object

# %%
plt.figure(figsize=(50,8))
ax=sns.countplot(x='Date',data=ava)
plt.xticks(rotation=90)
print(ava['Date'].value_counts())
# Out:
# 27-12-2015    108
# 24-12-2017    108
# 10-12-2017    108
# 03-12-2017    108
# 26-11-2017    108
#              ...
# 06-11-2016    108
# 07-01-2018    108
# 18-06-2017    107
# 25-06-2017    107
# 06-12-2015    107
# Name: Date, Length: 169, dtype: int64

# %% [markdown]
# Observations: We will convert this data into ordinal data later.

# %%
ax=sns.countplot(x='type',data=ava)
print(ava['type'].value_counts())
# Out:
# conventional    9126
# organic         9123
# Name: type, dtype: int64

# %% [markdown]
# Observations: Both conventional & organic avocado are similar in number.

# %%
ax=sns.countplot(x='region',data=ava)
print(ava['region'].value_counts())
plt.xticks(rotation=90)
# Out:
# Albany                 338
# Sacramento             338
# Northeast              338
# NorthernNewEngland     338
# Orlando                338
# Philadelphia           338
# PhoenixTucson          338
# Pittsburgh             338
# Plains                 338
# Portland               338
# RaleighGreensboro      338
# RichmondNorfolk        338
# Roanoke                338
# SanDiego               338
# Atlanta                338
# SanFrancisco           338
# Seattle                338
# SouthCarolina          338
# SouthCentral           338
# Southeast              338
# Spokane                338
# StLouis                338
# Syracuse               338
# Tampa                  338
# TotalUS                338
# West                   338
# NewYork                338
# NewOrleansMobile       338
# Nashville              338
# Midsouth               338
# BaltimoreWashington    338
# Boise                  338
# Boston                 338
# BuffaloRochester       338
# ...

# %% [markdown]
# Observations:All the regions have the same number of observations to teh dataset.

# %%
sns.histplot(ava['AveragePrice'],kde=True)
# Out:
# <AxesSubplot:xlabel='AveragePrice', ylabel='Count'>

# %% [markdown]
# Observation: The average price is centered between 1.0 -1.5

# %%
sns.scatterplot(data = ava,x='Total Volume', y= 'Small Bags')
# Out:
# <AxesSubplot:xlabel='Total Volume', ylabel='Small Bags'>

# %%
sns.scatterplot(data = ava,x='Total Volume', y= 'Large Bags')
# Out:
# <AxesSubplot:xlabel='Total Volume', ylabel='Large Bags'>

# %%
sns.scatterplot(data = ava,x='Total Volume', y= 'XLarge Bags')
# Out:
# <AxesSubplot:xlabel='Total Volume', ylabel='XLarge Bags'>

# %% [markdown]
# Observation: There seems to be a positive correlation between small bags &
#     Total volume and big bags but same cannot be said regarding Xl bags.

# %% [markdown]
# To see the proportion of organic vs conventional avocaos

# %%
sns.countplot(ava['year'])
ava['year'].value_counts()
# Out:
# 2017    5722
# 2016    5616
# 2015    5615
# 2018    1296
# Name: year, dtype: int64

# %% [markdown]
# Observation: Dataset contains datas of 4 years between 2015-2018

# %%
sns.scatterplot(y="type", x="AveragePrice", data=ava)
# Out:
# <AxesSubplot:xlabel='AveragePrice', ylabel='type'>

# %% [markdown]
#  Observation:Organic Avocado price is more as compared to conventional fruit.

# %%
sns.scatterplot(x='4046', y='AveragePrice', data= ava)
# Out:
# <AxesSubplot:xlabel='4046', ylabel='AveragePrice'>

# %%
sns.scatterplot(x='4225', y='AveragePrice', data= ava)
# Out:
# <AxesSubplot:xlabel='4225', ylabel='AveragePrice'>

# %%
sns.scatterplot(x='4770', y='AveragePrice', data= ava)
# Out:
# <AxesSubplot:xlabel='4770', ylabel='AveragePrice'>

# %% [markdown]
# Encoding

# %% [markdown]
# We shall adopt Ordinal Encoder to transform the all Non-numerical column into Numerical Data

# %%
from sklearn.preprocessing import OrdinalEncoder,LabelEncoder

# %%
oe=OrdinalEncoder()
le=LabelEncoder()

# %%
#converting Date which is in string to ordinal data
ava['Date']=oe.fit_transform(ava['Date'].values.reshape(-1,1))
ava['type']=le.fit_transform(ava['type'].values.reshape(-1,1))
ava['region']=oe.fit_transform(ava['region'].values.reshape(-1,1))
ava
# Out:
#         Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0      150.0          1.33      64236.62  1036.74   54454.85   48.16
# 1      111.0          1.35      54876.98   674.28   44638.81   58.33
# 2       72.0          0.93     118220.22   794.70  109149.67  130.50
# 3       33.0          1.08      78992.15  1132.00   71976.41   72.58
# 4      160.0          1.28      51039.60   941.48   43838.39   75.78
# ...      ...           ...           ...      ...        ...     ...
# 18244   17.0          1.63      17074.83  2046.96    1529.20    0.00
# 18245  151.0          1.71      13888.04  1191.70    3431.50    0.00
# 18246  112.0          1.87      13766.76  1191.92    2452.79  727.94
# 18247   73.0          1.93      16205.22  1527.63    2981.04  727.01
# 18248   34.0          1.62      17489.58  2894.77    2356.13  224.53
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags  type  year  region
# ...

# %% [markdown]
# Observations: All object columns have been encoded.

# %% [markdown]
# Check for normal distribution and see how data is distributed for every column

# %%
sns.distplot(ava['Date'],kde=True)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Density'>

# %%
sns.distplot(ava['AveragePrice'],kde=True)
# Out:
# <AxesSubplot:xlabel='AveragePrice', ylabel='Density'>

# %%
sns.distplot(ava['Total Volume'],kde=True)
# Out:
# <AxesSubplot:xlabel='Total Volume', ylabel='Density'>

# %%
sns.distplot(ava['4046'],kde=True)
# Out:
# <AxesSubplot:xlabel='4046', ylabel='Density'>

# %%
sns.distplot(ava['4225'],kde=True)
# Out:
# <AxesSubplot:xlabel='4225', ylabel='Density'>

# %%
sns.distplot(ava['4770'],kde=True)
# Out:
# <AxesSubplot:xlabel='4770', ylabel='Density'>

# %%
sns.distplot(ava['Total Bags'],kde=True)
# Out:
# <AxesSubplot:xlabel='Total Bags', ylabel='Density'>

# %%
sns.distplot(ava['Small Bags'],kde=True)
# Out:
# <AxesSubplot:xlabel='Small Bags', ylabel='Density'>

# %%
sns.distplot(ava['Large Bags'],kde=True)
# Out:
# <AxesSubplot:xlabel='Large Bags', ylabel='Density'>

# %%
sns.distplot(ava['XLarge Bags'],kde=True)
# Out:
# <AxesSubplot:xlabel='XLarge Bags', ylabel='Density'>

# %%
sns.distplot(ava['type'],kde=True)
# Out:
# <AxesSubplot:xlabel='type', ylabel='Density'>

# %%
sns.distplot(ava['year'],kde=True)
# Out:
# <AxesSubplot:xlabel='year', ylabel='Density'>

# %%
sns.distplot(ava['region'],kde=True)
# Out:
# <AxesSubplot:xlabel='region', ylabel='Density'>

# %% [markdown]
# Observations:
#     We can see that All the features does not obey a normal distribution.
#
# The normal distribution of these features; Date, type & region has no contribution to our Model Building since they are categorical data

# %%
sns.pairplot(ava)

# %% [markdown]
# From the above scatter plot we can see a strong relationship between some of the features.

# %% [markdown]
# Correlation Check(Collinearity and Multicollinearity)- Multivariate Analysis

# %% [markdown]
#     Collinearity Between Feature and Label
#     Multicolinearity between features

# %% [markdown]
# Lets see/visualize the correlation between (Features vs Label) and (Features vs Features)

# %%
#checking for general correlation
ava.corr()
# Out:
#                   Date  AveragePrice  Total Volume      4046      4225  \
# Date          1.000000      0.031112     -0.010463 -0.010815 -0.013020
# AveragePrice  0.031112      1.000000     -0.192752 -0.208317 -0.172928
# Total Volume -0.010463     -0.192752      1.000000  0.977863  0.974181
# 4046         -0.010815     -0.208317      0.977863  1.000000  0.926110
# 4225         -0.013020     -0.172928      0.974181  0.926110  1.000000
# 4770         -0.009778     -0.179446      0.872202  0.833389  0.887855
# Total Bags   -0.005807     -0.177088      0.963047  0.920057  0.905787
# Small Bags   -0.004650     -0.174730      0.967238  0.925280  0.916031
# Large Bags   -0.009220     -0.172940      0.880640  0.838645  0.810015
# XLarge Bags  -0.000466     -0.117592      0.747157  0.699377  0.688809
# type         -0.000016      0.615845     -0.232434 -0.225819 -0.232289
# year         -0.004266      0.093197      0.017193  0.003353 -0.009559
# ...

# %%
#checking for correlation between each feature and Label
ava.corr()['AveragePrice'].sort_values()
# Out:
# 4046           -0.208317
# Total Volume   -0.192752
# 4770           -0.179446
# Total Bags     -0.177088
# Small Bags     -0.174730
# Large Bags     -0.172940
# 4225           -0.172928
# XLarge Bags    -0.117592
# region         -0.011716
# Date            0.031112
# year            0.093197
# type            0.615845
# AveragePrice    1.000000
# Name: AveragePrice, dtype: float64

# %%
#checking for correlation between each feature and Label
ava.corr()['region'].sort_values()
# Out:
# AveragePrice   -0.011716
# type           -0.000280
# year           -0.000055
# Date           -0.000027
# XLarge Bags     0.082281
# 4770            0.095252
# 4225            0.145726
# Small Bags      0.164702
# Total Volume    0.174176
# Total Bags      0.175256
# 4046            0.192073
# Large Bags      0.198768
# region          1.000000
# Name: region, dtype: float64

# %%
#Plotting a bar chart to visualize correlation through the stand-alone bars
plt.figure(figsize=(15,8))
ava.corr()['region'].sort_values(ascending=False).drop(['region']).plot(kind='barh', color='b')
plt.show()

# %%
#Plotting a bar chart to visualize correlation through the stand-alone bars
plt.figure(figsize=(15,8))
ava.corr()['AveragePrice'].sort_values(ascending=False).drop(['AveragePrice']).plot(kind='barh', color='b')
plt.show()

# %% [markdown]
# Multicollinearity Check

# %%
#Plotting a heatmap to show correlation through the brightness of the map-squares
plt.figure(figsize=(15,7))
sns.heatmap(ava.corr(),annot=True, linewidth=0,linecolor='black',fmt='.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
#         We can see there is a strong relation between TotalBags and 4770 ie, 0.79.
#
#         Type and AveragePrice ie, 0.62.
#
#         Total Volume & 4046 are strongly correlated with .98
#
#         4225 & 4046 are having 093 corelation.
#
#         XLarge Bags and Large bags are .71
#
#         Large bags have a corealtion of 0.20 with region
#
#         Other than that there is weak realation.

# %% [markdown]
# Multicollinearity:
#
# From the heatmap we can see that the ALMOST ALL pairs of features DOES NOT have noticeable correllation between them

# %% [markdown]
# Outlier Check

# %%
ava.plot(kind="box",subplots =True,layout=(3,5))
plt.figure(figsize=(10,10))

# %% [markdown]
# Observations on Outlier Check
# From the above visualization plot its evident that outliers are present in almost all columns.
# The outlier of the categorical data does not impact our model
#
# The outlier of the Target data does not impact our model.

# %% [markdown]
# Skewness Check

# %%
ava.skew()
# Out:
# Date             0.000042
# AveragePrice     0.580303
# Total Volume     9.007687
# 4046             8.648220
# 4225             8.942466
# 4770            10.159396
# Total Bags       9.756072
# Small Bags       9.540660
# Large Bags       9.796455
# XLarge Bags     13.139751
# type             0.000329
# year             0.215339
# region           0.000030
# dtype: float64

# %% [markdown]
# Observations on Skewness Check:
# Lets assume Skewness threshold is taken as +/-0.50.Meaning any value outside +/-0.50 contains skewness. Hence the below features are skewed:
#
# Total Volume
# 4046
# 4225
# 4770
# Total Bags
# Small Bags
# Large Bags
# XLarge Bags

# %% [markdown]
# DATA PREPROCESSING

# %% [markdown]
# Removal of Duplicates and Unwanted Columns

# %%
#Recheking shape of original data
ava.shape
# Out:
# (18249, 13)

# %%
#Remove duplicates
ava.drop_duplicates(inplace=True)
ava.shape
# Out:
# (18249, 13)

# %% [markdown]
# It appears there are no duplicates since there is no change in the number of rows.

# %% [markdown]
# Dropping of Features that strongly promotes multicollinearity(VIF)

# %% [markdown]
# Variance Inflation Factor(VIF)

# %% [markdown]
# To solve this multicollinearity problem, we have to first scale our data using Standard Scaler

# %%
import statsmodels.api as sm
from scipy import stats
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %% [markdown]
# We will first use Region as the target variable.

# %%
x=ava.drop(columns=['region'])
y=ava['region']

# %%
print(x.shape)
print(y.shape)
# Out:
# (18249, 12)
# (18249,)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scalar=StandardScaler()
x_Scaled = scalar.fit_transform(x)
x_Scaled
# Out:
# array([[ 1.35285788, -0.18868864, -0.22771641, ..., -0.17557961,
#         -0.99983562, -1.22128204],
#        [ 0.55345115, -0.13901962, -0.23042664, ..., -0.17557961,
#         -0.99983562, -1.22128204],
#        [-0.24595558, -1.18206895, -0.21208462, ..., -0.17557961,
#         -0.99983562, -1.22128204],
#        ...,
#        [ 0.57394876,  1.15237477, -0.24233073, ..., -0.17557961,
#          1.00016441,  1.97050371],
#        [-0.22545797,  1.30138182, -0.24162464, ..., -0.17557961,
#          1.00016441,  1.97050371],
#        [-1.0248647 ,  0.53151208, -0.24125273, ..., -0.17557961,
#          1.00016441,  1.97050371]])

# %%
#checking the shape
x_Scaled.shape
# Out:
# (18249, 12)

# %%
#creating an empty dataframe stored in vif
vif=pd.DataFrame()

# %%
vif['vif']=[variance_inflation_factor(x_Scaled, i) for i in range(x_Scaled.shape[1])]

# %%
vif['Features'] = x.columns
vif
# Out:
#              vif      Features
# 0   1.002450e+00          Date
# 1   1.687769e+00  AveragePrice
# 2   4.924448e+09  Total Volume
# 3   6.606894e+08          4046
# 4   5.986393e+08          4225
# 5   4.768288e+06          4770
# 6   2.370316e+14    Total Bags
# 7   1.364727e+14    Small Bags
# 8   1.448103e+13    Large Bags
# 9   7.620691e+10   XLarge Bags
# 10  1.680887e+00          type
# 11  1.062821e+00          year

# %% [markdown]
# From the above vif dataframe,we are setting a vif threshold of 7, then there is no multi collinearity here.

# %% [markdown]
# Removal of Outliers

# %%
from scipy.stats import zscore

# %%
zscore(ava)
# Out:
#            Date  AveragePrice  Total Volume      4046      4225      4770  \
# 0      1.352858     -0.188689     -0.227716 -0.230816 -0.199902 -0.212091
# 1      0.553451     -0.139020     -0.230427 -0.231103 -0.208054 -0.211997
# 2     -0.245956     -1.182069     -0.212085 -0.231007 -0.154478 -0.211325
# 3     -1.045362     -0.809551     -0.223444 -0.230741 -0.185350 -0.211864
# 4      1.557834     -0.312861     -0.231538 -0.230891 -0.208719 -0.211834
# ...         ...           ...           ...       ...       ...       ...
# 18244 -1.373324      0.556347     -0.241373 -0.230017 -0.243857 -0.212540
# 18245  1.373355      0.755023     -0.242296 -0.230693 -0.242277 -0.212540
# 18246  0.573949      1.152375     -0.242331 -0.230693 -0.243090 -0.205766
# 18247 -0.225458      1.301382     -0.241625 -0.230428 -0.242651 -0.205774
# 18248 -1.024865      0.531512     -0.241253 -0.229347 -0.243170 -0.210450
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags      type      year  \
# ...

# %%
np.abs(zscore(ava))
# Out:
#            Date  AveragePrice  Total Volume      4046      4225      4770  \
# 0      1.352858      0.188689      0.227716  0.230816  0.199902  0.212091
# 1      0.553451      0.139020      0.230427  0.231103  0.208054  0.211997
# 2      0.245956      1.182069      0.212085  0.231007  0.154478  0.211325
# 3      1.045362      0.809551      0.223444  0.230741  0.185350  0.211864
# 4      1.557834      0.312861      0.231538  0.230891  0.208719  0.211834
# ...         ...           ...           ...       ...       ...       ...
# 18244  1.373324      0.556347      0.241373  0.230017  0.243857  0.212540
# 18245  1.373355      0.755023      0.242296  0.230693  0.242277  0.212540
# 18246  0.573949      1.152375      0.242331  0.230693  0.243090  0.205766
# 18247  0.225458      1.301382      0.241625  0.230428  0.242651  0.205774
# 18248  1.024865      0.531512      0.241253  0.229347  0.243170  0.210450
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags      type      year  \
# ...

# %%
#checking the data shape
z=np.abs(zscore(ava))
z.shape
# Out:
# (18249, 13)

# %%
len(np.where(z>3)[0])
# Out:
# 1773

# %%
#index number
np.where(z>3)
# Out:
# (array([  346,   359,   780, ..., 17304, 17402, 17428], dtype=int64),
#  array([3, 3, 9, ..., 1, 1, 1], dtype=int64))

# %%
#Extracting out the non-outliers(i.e zscore<3) and storing output in new object
ava_new=ava[(z<3).all(axis=1)]
print("Old DataFrame",ava.shape)
print("New DataFrame",ava_new.shape)
print("total_dropped_rows",ava.shape[0]-ava_new.shape[0])
print("Percentage of total_dropped_rows",(ava.shape[0]-ava_new.shape[0])/100)
# Out:
# Old DataFrame (18249, 13)
# New DataFrame (17651, 13)
# total_dropped_rows 598
# Percentage of total_dropped_rows 5.98

# %% [markdown]
# approx 6% of the data has outliers and we removing the same.

# %%
ava_new
# Out:
#         Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0      150.0          1.33      64236.62  1036.74   54454.85   48.16
# 1      111.0          1.35      54876.98   674.28   44638.81   58.33
# 2       72.0          0.93     118220.22   794.70  109149.67  130.50
# 3       33.0          1.08      78992.15  1132.00   71976.41   72.58
# 4      160.0          1.28      51039.60   941.48   43838.39   75.78
# ...      ...           ...           ...      ...        ...     ...
# 18244   17.0          1.63      17074.83  2046.96    1529.20    0.00
# 18245  151.0          1.71      13888.04  1191.70    3431.50    0.00
# 18246  112.0          1.87      13766.76  1191.92    2452.79  727.94
# 18247   73.0          1.93      16205.22  1527.63    2981.04  727.01
# 18248   34.0          1.62      17489.58  2894.77    2356.13  224.53
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags  type  year  region
# ...

# %%
ava_new.shape
# Out:
# (17651, 13)

# %%
#Lets reset our data having removed outliers
ava_new.reset_index(inplace=True)
ava_new
# Out:
#        index   Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0          0  150.0          1.33      64236.62  1036.74   54454.85   48.16
# 1          1  111.0          1.35      54876.98   674.28   44638.81   58.33
# 2          2   72.0          0.93     118220.22   794.70  109149.67  130.50
# 3          3   33.0          1.08      78992.15  1132.00   71976.41   72.58
# 4          4  160.0          1.28      51039.60   941.48   43838.39   75.78
# ...      ...    ...           ...           ...      ...        ...     ...
# 17646  18244   17.0          1.63      17074.83  2046.96    1529.20    0.00
# 17647  18245  151.0          1.71      13888.04  1191.70    3431.50    0.00
# 17648  18246  112.0          1.87      13766.76  1191.92    2452.79  727.94
# 17649  18247   73.0          1.93      16205.22  1527.63    2981.04  727.01
# 17650  18248   34.0          1.62      17489.58  2894.77    2356.13  224.53
#
# ...

# %%
#dropping the index columns which is not needed
ava_new.drop('index', axis=1,inplace=True)
ava_new
# Out:
#         Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0      150.0          1.33      64236.62  1036.74   54454.85   48.16
# 1      111.0          1.35      54876.98   674.28   44638.81   58.33
# 2       72.0          0.93     118220.22   794.70  109149.67  130.50
# 3       33.0          1.08      78992.15  1132.00   71976.41   72.58
# 4      160.0          1.28      51039.60   941.48   43838.39   75.78
# ...      ...           ...           ...      ...        ...     ...
# 17646   17.0          1.63      17074.83  2046.96    1529.20    0.00
# 17647  151.0          1.71      13888.04  1191.70    3431.50    0.00
# 17648  112.0          1.87      13766.76  1191.92    2452.79  727.94
# 17649   73.0          1.93      16205.22  1527.63    2981.04  727.01
# 17650   34.0          1.62      17489.58  2894.77    2356.13  224.53
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags  type  year  region
# ...

# %% [markdown]
# Transforming Data to Remove Skewness using Power transformation

# %%
ava.skew()
# Out:
# Date             0.000042
# AveragePrice     0.580303
# Total Volume     9.007687
# 4046             8.648220
# 4225             8.942466
# 4770            10.159396
# Total Bags       9.756072
# Small Bags       9.540660
# Large Bags       9.796455
# XLarge Bags     13.139751
# type             0.000329
# year             0.215339
# region           0.000030
# dtype: float64

# %%
ava_new.skew()
# Out:
# Date           -0.002634
# AveragePrice    0.377432
# Total Volume    3.767138
# 4046            4.909848
# 4225            4.455745
# 4770            5.117170
# Total Bags      4.066771
# Small Bags      4.222706
# Large Bags      5.053434
# XLarge Bags     6.135607
# type           -0.037741
# year            0.229976
# region          0.012798
# dtype: float64

# %% [markdown]
# From the above the most of the features are skewed based on a threshold of +/-0.5. We will do power transform to bring down the skewness.

# %%
from sklearn.preprocessing import power_transform

# %%
x=ava_new.iloc[:,0:-1]
y=ava_new.iloc[:,-1]
print(x.shape)
print(y.shape)
# Out:
# (17651, 12)
# (17651,)

# %%
ava_new['region'].nunique()
# Out:
# 54

# %%
y.nunique()
# Out:
# 54

# %%
x=power_transform(x,method= 'yeo-johnson')
x
# Out:
# array([[ 1.26088311, -0.11782446, -0.07532391, ..., -0.67791909,
#         -1.01904715, -1.2106467 ],
#        [ 0.5943227 , -0.06432986, -0.14749743, ..., -0.67791909,
#         -1.01904715, -1.2106467 ],
#        [-0.14324492, -1.29886469,  0.20555557, ..., -0.67791909,
#         -1.01904715, -1.2106467 ],
#        ...,
#        [ 0.61216387,  1.18432357, -0.77527398, ..., -0.67791909,
#          0.98130886,  1.97870686],
#        [-0.12311304,  1.31329624, -0.70179733, ..., -0.67791909,
#          0.98130886,  1.97870686],
#        [-0.9847875 ,  0.61561867, -0.66738095, ..., -0.67791909,
#          0.98130886,  1.97870686]])

# %% [markdown]
#  MODEL BUILDING

# %% [markdown]
# KNN Regressor

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score,classification_report
from sklearn.model_selection import cross_val_score

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=88,test_size=0.25)

# %%
knn=KNeighborsClassifier()

# %%
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
knn.score(x_train,y_train)
# Out:
# 0.8195346729113159

# %%
x_pred=knn.predict(x_test)
x_pred
# Out:
# array([41., 31., 16., ...,  0., 10., 10.])

# %%
acc_knn=round(accuracy_score(y_test,x_pred),2)
acc_knn
# Out:
# 0.68

# %%
confusion_matrix(y_test,x_pred)
# Out:
# array([[70,  0,  0, ...,  0,  0,  0],
#        [ 0, 50,  0, ...,  0,  0,  0],
#        [ 0,  0, 60, ...,  0,  0,  0],
#        ...,
#        [ 0,  0,  0, ..., 51,  0,  0],
#        [ 0,  0,  0, ...,  0, 50,  0],
#        [ 0,  4,  3, ...,  0,  0, 43]], dtype=int64)

# %%
cf=confusion_matrix(y_test,x_pred)
sns.heatmap(cf,annot=True)
# Out:
# <AxesSubplot:>

# %%
cl_report=classification_report(y_test,x_pred)
print(cl_report)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.57      0.93      0.71        75
#          1.0       0.45      0.53      0.48        95
#          2.0       0.71      0.91      0.80        66
#          3.0       0.63      0.75      0.68        76
#          4.0       0.79      0.84      0.81        98
#          5.0       0.46      0.53      0.49        72
#          6.0       0.80      0.84      0.82        61
#          7.0       0.54      0.78      0.64        74
#          8.0       0.91      0.89      0.90        81
#          9.0       0.66      0.62      0.64        98
#         10.0       0.48      0.57      0.52        88
#         11.0       0.65      0.79      0.71        84
#         12.0       0.85      0.77      0.81        82
#         13.0       0.55      0.61      0.58        76
#         14.0       0.88      0.85      0.86        84
#         15.0       0.88      0.86      0.87        79
# ...

# %% [markdown]
# Checking for overfitting in KNN Regression model.

# %% [markdown]
# Cross Validation of KNN Regression

# %%
from sklearn.model_selection import cross_val_score

# %%
scr=cross_val_score(knn,x,y,cv=5)
print(scr)
knncv_scr=round(scr.mean(),2)
print(round(scr.std()),2)
print("The cv score for KNN Regression:",knncv_scr)
# Out:
# [0.54205607 0.45949008 0.56713881 0.49150142 0.398017  ]
# 0 2
# The cv score for KNN Regression: 0.49

# %% [markdown]
# Difference between KNN Accuracy Score and Cross Validation Score

# %%
acc_knn_vs_knncv_scr=np.abs(acc_knn-knncv_scr)
print("Difference between Accuracy and Cross Validation Score = ",acc_knn-knncv_scr)
# Out:
# Difference between Accuracy and Cross Validation Score =  0.19000000000000006

# %% [markdown]
# Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20)

# %%
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
lr.intercept_
# Out:
# array([ -1.68648   ,   2.39611791,   1.5678027 ,  -2.79401658,
#          0.93344012,  -0.43975416,  -6.96927964,  -1.63642304,
#         -0.29579075,   1.27619386,   2.24950762,   1.01337824,
#          2.91157044,   4.16205856,  -0.52125057,  -2.93463388,
#          3.50261682,  -0.09220671,   0.97536647,   0.75666765,
#          0.6862551 ,   3.31746785,  -0.50864553,  -4.28899573,
#          2.27213371,  -2.58583072,   2.11227689,   0.89290006,
#         -0.78444422,  -6.60928745,   1.5217741 ,   1.43692304,
#          3.55277411,   1.51709744,   1.02262341,   2.17899304,
#          3.57354466,   0.55789319,   2.42224383,   1.60208617,
#         -0.88224374,   3.86566708,  -2.51271406,   3.3450522 ,
#          2.64547194,  -5.23803556,  -1.07768571,  -0.39777777,
#          1.60099809,  -5.38653344,   1.37763273, -12.32352385,
#         -6.52727601,   3.24630007])

# %%
lr.coef_
# Out:
# array([[-4.70179877e-02, -7.69446266e-01, -5.64224169e-01,
#         -4.88669749e+00, -2.06334799e+00, -1.63913352e+00,
#         -3.07482643e+00, -1.88268154e+00, -1.93510058e+00,
#          1.81419937e-01, -1.03987666e+01,  1.53273150e+00],
#        [ 4.27450231e-02, -5.12685565e-01,  2.31899382e+00,
#          2.24466364e+00, -2.83560558e+00, -2.54431617e+00,
#         -8.59282031e-01, -1.76064509e+00,  1.90820722e+00,
#          1.81197785e-01, -7.44249254e-01, -7.15081540e-02],
#        [-2.19108132e-02,  1.00097471e+00, -2.03858215e+00,
#         -1.33931810e+00,  5.33751819e+00,  3.50844779e+00,
#          1.85328500e+00,  1.34599546e+00, -1.85240232e+00,
#         -5.47223728e-01,  4.22170449e+00,  2.41062901e-02],
#        [-1.27997251e-01, -2.54751301e+00, -1.39849180e+00,
#         -4.12316407e+00, -4.91640187e+00,  1.10869707e+00,
#         -3.63473855e+00, -3.89926746e+00, -2.51570732e-01,
#          7.32892091e-01, -1.01233116e+01,  1.69620658e+00],
# ...

# %%
pred=lr.predict(x_test)
pred
# Out:
# array([14., 17., 27., ..., 26., 38.,  6.])

# %%
acc_lr=round(accuracy_score(y_test,pred),2)
acc_lr
# Out:
# 0.56

# %%
cf=confusion_matrix(y_test,pred)
sns.heatmap(cf,annot=True)
# Out:
# <AxesSubplot:>

# %%
cl_report=classification_report(y_test,pred)
print(cl_report)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.66      0.72      0.69        71
#          1.0       0.21      0.37      0.26        63
#          2.0       0.68      0.63      0.65        54
#          3.0       0.77      0.46      0.58        74
#          4.0       0.46      0.42      0.44        55
#          5.0       0.64      0.51      0.57        74
#          6.0       0.85      0.85      0.85        75
#          7.0       0.59      0.66      0.63        71
#          8.0       0.76      0.80      0.78        69
#          9.0       0.53      0.78      0.63        55
#         10.0       0.44      0.35      0.39        68
#         11.0       0.71      0.73      0.72        70
#         12.0       0.51      0.60      0.55        65
#         13.0       0.46      0.32      0.38        68
#         14.0       0.55      0.60      0.58        70
#         15.0       0.67      0.56      0.61        57
# ...

# %%
scr=cross_val_score(lr,x,y,cv=5)
print(scr)
lrcv_scr=round(scr.mean(),2)
print(round(scr.std()),2)
print("The cv score for Linear Regression:",lrcv_scr)
# Out:
# [0.34919286 0.40254958 0.46033994 0.47252125 0.31189802]
# 0 2
# The cv score for Linear Regression: 0.4

# %% [markdown]
# Difference between Logistic Regression Accuracy Score and Cross Validation Score

# %%
acc_lr_vs_lrcv_scr=np.abs(acc_lr-lrcv_scr)
print("Difference between Accuracy and Cross Validation Score = ",acc_lr-lrcv_scr)
# Out:
# Difference between Accuracy and Cross Validation Score =  0.16000000000000003

# %% [markdown]
# Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtc=DecisionTreeClassifier()

# %%
dtc.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred=dtc.predict(x_test)
pred
# Out:
# array([14.,  4., 34., ..., 27., 38.,  6.])

# %%
acc_dtc=round(accuracy_score(y_test,pred),2)
acc_dtc
# Out:
# 0.79

# %%
confusion_matrix(y_test,pred)
# Out:
# array([[50,  0,  0, ...,  0,  0,  0],
#        [ 0, 47,  0, ...,  0,  0,  0],
#        [ 0,  0, 46, ...,  0,  0,  1],
#        ...,
#        [ 0,  0,  0, ..., 36,  0,  0],
#        [ 0,  2,  0, ...,  0, 41,  0],
#        [ 0,  0,  0, ...,  0,  0, 38]], dtype=int64)

# %%
cf=confusion_matrix(y_test,pred)
sns.heatmap(cf,annot=True)
# Out:
# <AxesSubplot:>

# %%
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.70      0.70      0.70        71
#          1.0       0.75      0.75      0.75        63
#          2.0       0.85      0.85      0.85        54
#          3.0       0.80      0.77      0.79        74
#          4.0       0.91      0.89      0.90        55
#          5.0       0.74      0.66      0.70        74
#          6.0       0.94      0.96      0.95        75
#          7.0       0.84      0.87      0.86        71
#          8.0       0.94      0.88      0.91        69
#          9.0       0.74      0.82      0.78        55
#         10.0       0.63      0.75      0.68        68
#         11.0       0.86      0.84      0.85        70
#         12.0       0.84      0.89      0.87        65
#         13.0       0.66      0.57      0.61        68
#         14.0       0.82      0.86      0.84        70
#         15.0       0.95      0.91      0.93        57
# ...

# %% [markdown]
# Cross Validation of Decision Tree Classifier

# %%
dtc_scr=cross_val_score(dtc,x,y,cv=5)
print(dtc_scr)
dtccv_scr=round(dtc_scr.mean(),2)
print(round(dtc_scr.std()),2)
print("The cv score for Decision Tree:",dtccv_scr)
# Out:
# [0.48003398 0.67280453 0.63456091 0.5427762  0.42832861]
# 0 2
# The cv score for Decision Tree: 0.55

# %% [markdown]
# Difference between Decision Tree Classifier Accuracy Score and Cross Validation Score

# %%
acc_dtc_vs_dtccv_scr=np.abs(acc_dtc-dtccv_scr)
print("Difference between Accuracy and Cross Validation Score = ",acc_dtc_vs_dtccv_scr)
# Out:
# Difference between Accuracy and Cross Validation Score =  0.24

# %% [markdown]
# Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf=RandomForestClassifier()

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
pred=rf.predict(x_test)
pred
# Out:
# array([14.,  4., 34., ..., 27., 38.,  6.])

# %%
acc_rf=round(accuracy_score(y_test,pred),2)
acc_rf
# Out:
# 0.9

# %%
confusion_matrix(y_test,pred)
cf=confusion_matrix(y_test,pred)
cf
# Out:
# array([[67,  0,  0, ...,  0,  0,  0],
#        [ 0, 56,  0, ...,  0,  0,  0],
#        [ 0,  0, 53, ...,  0,  0,  0],
#        ...,
#        [ 0,  0,  0, ..., 37,  0,  0],
#        [ 0,  0,  0, ...,  1, 45,  0],
#        [ 0,  0,  0, ...,  0,  0, 44]], dtype=int64)

# %%
sns.heatmap(cf,annot=True)
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.87      0.94      0.91        71
#          1.0       0.85      0.89      0.87        63
#          2.0       0.95      0.98      0.96        54
#          3.0       0.90      0.84      0.87        74
#          4.0       0.92      0.98      0.95        55
#          5.0       0.92      0.74      0.82        74
#          6.0       0.95      1.00      0.97        75
#          7.0       0.91      0.97      0.94        71
#          8.0       0.96      0.99      0.97        69
#          9.0       0.83      0.89      0.86        55
#         10.0       0.77      0.84      0.80        68
#         11.0       0.93      0.97      0.95        70
#         12.0       0.95      0.97      0.96        65
#         13.0       0.95      0.79      0.86        68
#         14.0       0.93      0.90      0.91        70
#         15.0       1.00      0.98      0.99        57
# ...

# %% [markdown]
# Cross validation of Random Forest

# %%
rf_scr=cross_val_score(rf,x,y,cv=5)
print(rf_scr)
rfcv_scr=round(rf_scr.mean(),2)
print(round(rf_scr.std()),2)
print("The cv score for Random Forest:",rfcv_scr)
# Out:
# [0.63098272 0.81331445 0.73796034 0.701983   0.4898017 ]
# 0 2
# The cv score for Random Forest: 0.67

# %% [markdown]
# Difference between Random Forest Accuracy Score and Cross Validation Score

# %%
acc_rf_vs_rfcv_scr=np.abs(acc_rf-rfcv_scr)
print("Difference between Accuracy and Cross Validation Score = ",acc_rf_vs_rfcv_scr)
# Out:
# Difference between Accuracy and Cross Validation Score =  0.22999999999999998

# %% [markdown]
# SVC

# %%
from sklearn.svm import SVC

# %%
svc=SVC()

# %%
svc.fit(x_train,y_train)
# Out:
# SVC()

# %%
pred=svc.predict(x_test)
pred
# Out:
# array([14.,  4., 34., ..., 27., 38.,  6.])

# %%
acc_svc=round(accuracy_score(y_test,pred),2)
acc_svc
# Out:
# 0.8

# %%
confusion_matrix(y_test,pred)
cf=confusion_matrix(y_test,pred)
cf
# Out:
# array([[65,  0,  0, ...,  0,  0,  0],
#        [ 0, 36,  0, ...,  0,  0,  1],
#        [ 0,  0, 54, ...,  0,  0,  0],
#        ...,
#        [ 0,  0,  0, ..., 37,  0,  0],
#        [ 0,  0,  0, ...,  0, 44,  0],
#        [ 0,  1,  1, ...,  0,  0, 37]], dtype=int64)

# %%
sns.heatmap(cf,annot=True)
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.71      0.92      0.80        71
#          1.0       0.49      0.57      0.53        63
#          2.0       0.96      1.00      0.98        54
#          3.0       0.95      0.72      0.82        74
#          4.0       0.91      0.87      0.89        55
#          5.0       0.89      0.65      0.75        74
#          6.0       1.00      0.96      0.98        75
#          7.0       0.80      0.79      0.79        71
#          8.0       0.97      0.99      0.98        69
#          9.0       0.73      0.82      0.77        55
#         10.0       0.53      0.68      0.59        68
#         11.0       0.79      0.89      0.84        70
#         12.0       0.88      0.94      0.91        65
#         13.0       0.57      0.71      0.63        68
#         14.0       0.87      0.93      0.90        70
#         15.0       0.96      0.89      0.93        57
# ...

# %% [markdown]
# Cross validation of SVC

# %%
svc_scr=cross_val_score(svc,x,y,cv=5)
print(svc_scr)
svccv_scr=round(svc_scr.mean(),2)
print(round(svc_scr.std()),2)
print("The cv score for SVC:",svccv_scr)
# Out:
# [0.61823846 0.69461756 0.69150142 0.63994334 0.46997167]
# 0 2
# The cv score for SVC: 0.62

# %% [markdown]
# Difference between SVC Accuracy Score and Cross Validation Score

# %%
acc_svc_vs_svccv_scr=np.abs(acc_svc-svccv_scr)
print("Difference between Accuracy and Cross Validation Score = ",acc_svc_vs_svccv_scr)
# Out:
# Difference between Accuracy and Cross Validation Score =  0.18000000000000005

# %%
Model=pd.DataFrame({'ML_Models':['KNeighbors Regressor','Logistic Regression','Decision Tree Classifier','Random Forest','SVC'], 'Accuracy_Score':[acc_knn,acc_lr,acc_dtc,acc_rf,acc_svc],'Cross_Validation':[knncv_scr,lrcv_scr,dtccv_scr,rfcv_scr,svccv_scr],'Diff_betw_acc_cv_scr':[acc_knn_vs_knncv_scr,acc_lr_vs_lrcv_scr,acc_dtc_vs_dtccv_scr,acc_rf_vs_rfcv_scr,acc_svc_vs_svccv_scr]})
Model
# Out:
#                   ML_Models  Accuracy_Score  Cross_Validation  \
# 0      KNeighbors Regressor            0.68              0.49
# 1       Logistic Regression            0.56              0.40
# 2  Decision Tree Classifier            0.79              0.55
# 3             Random Forest            0.90              0.67
# 4                       SVC            0.80              0.62
#
#    Diff_betw_acc_cv_scr
# 0                  0.19
# 1                  0.16
# 2                  0.24
# 3                  0.23
# 4                  0.18

# %% [markdown]
# We will choose Random Forest as the best model as the accuracy score is best for this model though the difference in accuracy & cv score is 0.23.

# %% [markdown]
# Hyper Parameter tunning

# %%
from sklearn.model_selection import GridSearchCV

# %%
rf=RandomForestClassifier()

# %%
parameters={'max_features':['auto','sqrt','log2'],
           'max_depth':[4,5,6,7,8],
            'criterion' :['gini', 'entropy'],
            'n_estimators':[100,200,300,400,500]}

# %%
GSV=GridSearchCV(rf,parameters,cv=5)

# %%
GSV.fit(x_train,y_train)
GSV.best_params_

# %% [markdown]
# Saving the best model

# %%
ava_new['New_AveragePrice']=ava_new['AveragePrice']
ava_new.drop('AveragePrice', axis=1, inplace=True)
ava_new
# Out:
#         Date  Total Volume     4046       4225    4770  Total Bags  \
# 0      150.0      64236.62  1036.74   54454.85   48.16     8696.87
# 1      111.0      54876.98   674.28   44638.81   58.33     9505.56
# 2       72.0     118220.22   794.70  109149.67  130.50     8145.35
# 3       33.0      78992.15  1132.00   71976.41   72.58     5811.16
# 4      160.0      51039.60   941.48   43838.39   75.78     6183.95
# ...      ...           ...      ...        ...     ...         ...
# 17646   17.0      17074.83  2046.96    1529.20    0.00    13498.67
# 17647  151.0      13888.04  1191.70    3431.50    0.00     9264.84
# 17648  112.0      13766.76  1191.92    2452.79  727.94     9394.11
# 17649   73.0      16205.22  1527.63    2981.04  727.01    10969.54
# 17650   34.0      17489.58  2894.77    2356.13  224.53    12014.15
#
#        Small Bags  Large Bags  XLarge Bags  type  year  region  \
# 0         8603.62       93.25          0.0     0  2015     0.0
# ...

# %%
from sklearn.preprocessing import power_transform

# %%
x=ava_new.iloc[:,0:-1]
y=ava_new.iloc[:,-1]
print(x.shape)
print(y.shape)
# Out:
# (17651, 12)
# (17651,)

# %%
x=power_transform(x,method= 'yeo-johnson')
x
# Out:
# array([[ 1.26088311, -0.07532391, -0.65742071, ..., -1.01904715,
#         -1.2106467 , -2.01058988],
#        [ 0.5943227 , -0.14749743, -0.77717852, ..., -1.01904715,
#         -1.2106467 , -2.01058988],
#        [-0.14324492,  0.20555557, -0.7317763 , ..., -1.01904715,
#         -1.2106467 , -2.01058988],
#        ...,
#        [ 0.61216387, -0.77527398, -0.61796649, ...,  0.98130886,
#          1.97870686,  1.57828237],
#        [-0.12311304, -0.70179733, -0.54701087, ...,  0.98130886,
#          1.97870686,  1.57828237],
#        [-0.9847875 , -0.66738095, -0.35967077, ...,  0.98130886,
#          1.97870686,  1.57828237]])

# %% [markdown]
# Model Building with Y label as Average Price.

# %% [markdown]
# Linear Regression

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.model_selection import cross_val_score

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20)

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_train,y_train)
# Out:
# 0.5269984957660008

# %%
x_predict=lr.predict(x_test)

# %%
x_predict
# Out:
# array([1.40887783, 1.80725871, 1.65504208, ..., 1.30418085, 1.77857504,
#        1.48504092])

# %%
lr.coef_
# Out:
# array([ 0.01066072, -0.29950268,  0.01267526,  0.25727722,  0.02308271,
#        -0.24925701,  0.2186397 , -0.03161088,  0.01024017,  0.18355205,
#         0.07700505,  0.01327558])

# %%
lr.intercept_
# Out:
# 1.404592780835539

# %%
print("Mean Absolute error:",mean_absolute_error(y_test,x_predict))
print("Mean Squared error:", mean_squared_error(y_test,x_predict))
print('Root Mean Squared error:',np.sqrt(mean_squared_error(y_test,x_predict)))
li_sc=(r2_score(y_test,x_predict))
print("The test Accuracy score for linear regression is",li_sc)
# Out:
# Mean Absolute error: 0.2088258242531566
# Mean Squared error: 0.07022324853434844
# Root Mean Squared error: 0.26499669532722187
# The test Accuracy score for linear regression is 0.5331074598426331

# %% [markdown]
# Checking for overfitting in Linear Regression model.

# %%
scr=cross_val_score(lr,x,y,cv=5)
print(scr)
print(round(scr.std()),2)
lrcv_scr=round(svc_scr.mean(),2)
print("The cv score for Linear Regression:",lrcv_scr)
# Out:
# [-0.0273555   0.07782474  0.44071982  0.20164087  0.22223108]
# 0 2
# The cv score for Linear Regression: 0.62

# %% [markdown]
# Difference between Accuracy Score and Cross Validation Score

# %%
lr_Acc_vs_CV_Score=np.abs(li_sc-lrcv_scr)
print("Difference between Accuracy and Cross Validation Score = ",lr_Acc_vs_CV_Score)
# Out:
# Difference between Accuracy and Cross Validation Score =  0.08689254015736692

# %%
#Using KNeighbors Regressor 
from sklearn.neighbors import KNeighborsRegressor
knn=KNeighborsRegressor()

# %%
knn.fit(x_train,y_train)
# Out:
# KNeighborsRegressor()

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20)

# %%
knn.score(x_train,y_train)
# Out:
# 0.7964293971968807

# %%
predict_x=knn.predict(x_test)
predict_x
# Out:
# array([1.226, 1.138, 1.68 , ..., 2.114, 1.134, 1.754])

# %%
knn_acc_test=r2_score(y_test,predict_x)
print("Accuracy test score for KNN:", knn_acc_test)                
print("Mean Absolute error:",mean_absolute_error(y_test,predict_x))
print("Mean Squared error:", mean_squared_error(y_test,predict_x))
print('Root Mean Squared error:',np.sqrt(mean_squared_error(y_test,predict_x)))
# Out:
# Accuracy test score for KNN: 0.7983523148350371
# Mean Absolute error: 0.1263647691871991
# Mean Squared error: 0.030429565562163696
# Root Mean Squared error: 0.1744407222014507

# %% [markdown]
# Checking Cross Validation score

# %%
scr=cross_val_score(knn,x,y,cv=5)
print(scr)
print(scr.std())
cv_knn=scr.mean()
print('The CV score of Knn:',cv_knn)
# Out:
# [-0.02075691  0.22907812  0.44231244  0.24781096 -0.09503941]
# 0.1948839202437524
# The CV score of Knn: 0.16068104117380727

# %%
knn_acc_test_vs_CV_Score=np.abs(knn_acc_test-cv_knn)
print("Difference between Accuracy and Cross Validation Score of Knn = ",knn_acc_test_vs_CV_Score)
# Out:
# Difference between Accuracy and Cross Validation Score of Knn =  0.6376712736612298

# %% [markdown]
# SGD Regressor

# %%
from sklearn.linear_model import SGDRegressor
sgd=SGDRegressor(alpha=0.01)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20)

# %%
sgd.fit(x_train,y_train)
score=sgd.score(x_train,y_train)
predict_y=sgd.predict(x_test)
score_t=sgd.score(x_test,y_test)

# %%
sgd_acc_test=r2_score(y_test,predict_y)
print("Accuracy test score for sgd:", sgd_acc_test)                
print("Mean Absolute error:",mean_absolute_error(y_test,predict_y))
print("Mean Squared error:", mean_squared_error(y_test,predict_y))
print('Root Mean Squared error:',np.sqrt(mean_squared_error(y_test,predict_y)))
# Out:
# Accuracy test score for sgd: 0.5090188133045312
# Mean Absolute error: 0.21143863240728106
# Mean Squared error: 0.0720017457398439
# Root Mean Squared error: 0.26833141027439167

# %% [markdown]
# Checking Cross Validation score of SGDRegressor

# %%
sgd_sc=cross_val_score(sgd, x,y,cv=5)

print(sgd_sc)
print(sgd_sc.std())
cv_sgd=sgd_sc.mean()
print('The CV score of SGD:',cv_sgd)
# Out:
# [-0.01569586  0.10062809  0.47438787  0.22264365  0.19048136]
# 0.16256670511022794
# The CV score of SGD: 0.19448902109602934

# %% [markdown]
# Difference between Accuracy Score and Cross Validation Score

# %%
sgd_acc_test_vscv_sgd=np.abs(sgd_acc_test-cv_sgd)
print("Difference between Accuracy and Cross Validation Score of SGD Regressor= ",sgd_acc_test_vscv_sgd)
# Out:
# Difference between Accuracy and Cross Validation Score of SGD Regressor=  0.3145297922085019

# %% [markdown]
# Support Vector Regressor(SVR)

# %%
from sklearn.svm import SVR

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20)

# %%
svr=SVR()

# %%
svr.fit(x_train,y_train)
# Out:
# SVR()

# %%
score=svr.score(x_train,y_train)
predict_y=svr.predict(x_test)
score_t=svr.score(x_test,y_test)

# %%
svr_acc_test=r2_score(y_test,predict_y)
print("Accuracy test score for SVR:", svr_acc_test)                
print("Mean Absolute error:",mean_absolute_error(y_test,predict_y))
print("Mean Squared error:", mean_squared_error(y_test,predict_y))
print('Root Mean Squared error:',np.sqrt(mean_squared_error(y_test,predict_y)))
# Out:
# Accuracy test score for SVR: 0.7120696505758479
# Mean Absolute error: 0.15814866980551487
# Mean Squared error: 0.044476137681978584
# Root Mean Squared error: 0.21089366439506566

# %% [markdown]
# Checking Cross Validation score of SVR

# %%
svr_sc=cross_val_score(svr, x,y,cv=5)

print(svr_sc)
print(svr_sc.std())
cv_svr=svr_sc.mean()
print('The CV score of SGD:',cv_svr)
# Out:
# [-0.64959402  0.27079785  0.10634074  0.33278709  0.00176603]
# 0.35116701224659824
# The CV score of SGD: 0.012419539283644565

# %%
#Difference between Accuracy Score and Cross Validation Score
svr_acc_test_vscv_svr=np.abs(svr_acc_test-cv_svr)
print("Difference between Accuracy and Cross Validation Score of SGD Regressor= ",svr_acc_test_vscv_svr)
# Out:
# Difference between Accuracy and Cross Validation Score of SGD Regressor=  0.6996501112922033

# %% [markdown]
# GradientBoostingRegressor

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
gb=GradientBoostingRegressor()

# %%
gb.fit(x_train,y_train)
# Out:
# GradientBoostingRegressor()

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20)

# %%
#training score
gb.score(x_train,y_train)
# Out:
# 0.694115043067647

# %%
predict_y=gb.predict(x_test)

# %%
#testing score
gb_acc_test=r2_score(y_test,predict_y)
print("Accuracy test score for GB:", gb_acc_test)                
print("Mean Absolute error:",mean_absolute_error(y_test,predict_y))
print("Mean Squared error:", mean_squared_error(y_test,predict_y))
print('Root Mean Squared error:',np.sqrt(mean_squared_error(y_test,predict_y)))
# Out:
# Accuracy test score for GB: 0.6980460066957352
# Mean Absolute error: 0.15847291362785249
# Mean Squared error: 0.04411292039988967
# Root Mean Squared error: 0.2100307606039879

# %% [markdown]
# Checking Cross Validation score of GradientBoostingRegressor

# %%
gb_sc=cross_val_score(gb, x,y,cv=5)

print(gb_sc)
print(gb_sc.std())
cv_gb=gb_sc.mean()
print('The CV score of SGD:',cv_gb)
# Out:
# [0.25029512 0.39455865 0.56161772 0.34702716 0.16059858]
# 0.13589152125279716
# The CV score of SGD: 0.34281944526491437

# %% [markdown]
# Decision tree Regressor Model

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dtr=DecisionTreeRegressor()

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20)

# %%
dtr.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
dtr.score(x_train,y_train)
# Out:
# 1.0

# %%
predict_y=dtr.predict(x_test)

# %%
print("The absolute error is:",mean_absolute_error(y_test,predict_y))
print("The Mean Squared Error is:",mean_squared_error(y_test,predict_y))
print("The root mean squared error is:", np.sqrt(mean_squared_error(y_test,predict_y)))
dtr_acc_test=r2_score(y_test,predict_y)
print("The test score is:",r2_score(y_test,predict_y))
# Out:
# The absolute error is: 0.1461568960634381
# The Mean Squared Error is: 0.04801619937694704
# The root mean squared error is: 0.21912598973409575
# The test score is: 0.6769011143335995

# %% [markdown]
# Checking Cross Validation score of DecisionTreeRegressor

# %%
dtr_sc=cross_val_score(dtr, x,y,cv=5)

print(dtr_sc)
print(dtr_sc.std())
cv_dtr=dtr_sc.mean()
print('The CV score of Decision Tree Regressor is:',cv_dtr)
# Out:
# [-1.40882049 -0.20126211  0.27857563 -0.54807661 -0.39261165]
# 0.55223973991363
# The CV score of Decision Tree Regressor is: -0.45443904516423217

# %%
#Difference between Accuracy Score and Cross Validation Score
dtr_acc_test_vs_cv_dtr=np.abs(dtr_acc_test-cv_dtr)
print("Difference between Accuracy and Cross Validation Score of SGD Regressor= ",dtr_acc_test_vs_cv_dtr)
# Out:
# Difference between Accuracy and Cross Validation Score of SGD Regressor=  1.1691686165432431

# %% [markdown]
# Creating a dataframe that will show the metrics of all the models.

# %%
#Constructing a dataframe...
Models = pd.DataFrame({'ML_Model' : ['Linear Regression','KNeigbors Regressor','SGD Regressor','SVR','Decision Tree Regressor'],'Accuracy_Score' : [li_sc,knn_acc_test,sgd_acc_test,svr_acc_test,dtr_acc_test],'Cross_Validation_Score':[lrcv_scr,cv_knn,cv_sgd,cv_svr,cv_dtr],'Accuracy_VS_CVScore':[lr_Acc_vs_CV_Score,knn_acc_test_vs_CV_Score,sgd_acc_test_vscv_sgd,svr_acc_test_vscv_svr,dtr_acc_test_vs_cv_dtr] })
Models
# Out:
#                   ML_Model  Accuracy_Score  Cross_Validation_Score  \
# 0        Linear Regression        0.533107                0.620000
# 1      KNeigbors Regressor        0.798352                0.160681
# 2            SGD Regressor        0.509019                0.194489
# 3                      SVR        0.712070                0.012420
# 4  Decision Tree Regressor        0.676901               -0.492268
#
#    Accuracy_VS_CVScore
# 0             0.086893
# 1             0.637671
# 2             0.314530
# 3             0.699650
# 4             1.169169

# %%
We will go ahead and save he Linear Regression model as that has the highets CV score.

# %%
MODEL SAVING

# %%
import pickle

# %%
filename='Machine_Model_ProjectAvocado'
pickle.dump(sgd,open(filename,'wb'))
