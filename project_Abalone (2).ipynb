# %%
import pandas as pd
import numpy as np

# %%
ab=pd.read_csv("abaloneds.csv")
ab
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %%
ab.columns
# Out:
# Index(['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight',
#        'Viscera weight', 'Shell weight', 'Rings', 'age'],
#       dtype='object')

# %% [markdown]
# As we have to determine age of Abalone so we are deleting the rings column

# %%
ab['age']=ab['Rings']+1.5
ab
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings   age
# 0             0.1010        0.1500     15  16.5
# 1             0.0485        0.0700      7   8.5
# ...

# %%
ab.drop('Rings', axis=1, inplace=True)

# %%
ab
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight   age
# 0             0.1010        0.1500  16.5
# 1             0.0485        0.0700   8.5
# 2             0.1415        0.2100  10.5
# ...

# %%
ab.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight   age
# 0         0.150  16.5
# 1         0.070   8.5
# 2         0.210  10.5
# 3         0.155  11.5
# 4         0.055   8.5

# %%
ab.tail()
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight   age
# 4172          0.2390        0.2490  12.5
# 4173          0.2145        0.2605  11.5
# 4174          0.2875        0.3080  10.5
# 4175          0.2610        0.2960  11.5
# 4176          0.3765        0.4950  13.5

# %%
ab.shape
# Out:
# (4177, 9)

# %%
#finding out the data types in each column
ab.dtypes
# Out:
# Sex                object
# Length            float64
# Diameter          float64
# Height            float64
# Whole weight      float64
# Shucked weight    float64
# Viscera weight    float64
# Shell weight      float64
# age               float64
# dtype: object

# %%
ab.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sex             4177 non-null   object
#  1   Length          4177 non-null   float64
#  2   Diameter        4177 non-null   float64
#  3   Height          4177 non-null   float64
#  4   Whole weight    4177 non-null   float64
#  5   Shucked weight  4177 non-null   float64
#  6   Viscera weight  4177 non-null   float64
#  7   Shell weight    4177 non-null   float64
#  8   age             4177 non-null   float64
# dtypes: float64(8), object(1)
# memory usage: 293.8+ KB

# %%
ab.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# age               0
# dtype: int64

# %% [markdown]
# As there are no null or empty cells in this dataset so no need to apply imputer library to handle Empty Cell or empty values

# %%
ab.drop_duplicates()
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight   age
# 0             0.1010        0.1500  16.5
# 1             0.0485        0.0700   8.5
# 2             0.1415        0.2100  10.5
# ...

# %% [markdown]
# Observation:There are no duplicates in the dataset.

# %%
import seaborn as sns

# %%
sns.heatmap(ab.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# Observations: Visualisation of no null data in the Data set.

# %% [markdown]
# Visualisation of the Data Set

# %% [markdown]
# Categorical data visualisation

# %%
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
sns.countplot(x='Sex',data = ab)
print(ab['Sex'].value_counts())
# Out:
# M    1528
# I    1342
# F    1307
# Name: Sex, dtype: int64

# %% [markdown]
# Observations: The male count in this dataset is 1528, followed by Infants & females.

# %%
ab.skew()
# Out:
# Length           -0.639873
# Diameter         -0.609198
# Height            3.128817
# Whole weight      0.530959
# Shucked weight    0.719098
# Viscera weight    0.591852
# Shell weight      0.620927
# age               1.114102
# dtype: float64

# %%
sns.distplot(ab['Length'],kde=True)
# Out:
# <AxesSubplot:xlabel='Length', ylabel='Density'>

# %% [markdown]
# Observation: The length of abalone is slightly skewed to the left.

# %%
sns.distplot(ab['Diameter'], kde=True)
# Out:
# <AxesSubplot:xlabel='Diameter', ylabel='Density'>

# %% [markdown]
# Observation: The diameter of abalone is slightly skewed to the left.

# %%
sns.distplot(ab['Height'], kde=True)
# Out:
# <AxesSubplot:xlabel='Height', ylabel='Density'>

# %% [markdown]
# Observations: This is falling under the normal distribution.

# %%
sns.distplot(ab['Whole weight'], kde=True)
# Out:
# <AxesSubplot:xlabel='Whole weight', ylabel='Density'>

# %% [markdown]
# Observation: The whole weight column is slightly skewed to the right.

# %%
sns.distplot(ab['Shucked weight'], kde=True)
# Out:
# <AxesSubplot:xlabel='Shucked weight', ylabel='Density'>

# %% [markdown]
# Observations: Shucked weight is not falling under the normal distribution.

# %%
sns.distplot(ab['Viscera weight'], kde=True)
# Out:
# <AxesSubplot:xlabel='Viscera weight', ylabel='Density'>

# %% [markdown]
# Observations: Shucked weight is not falling under the normal distribution.

# %%
sns.distplot(ab['Shell weight'], kde=True)
# Out:
# <AxesSubplot:xlabel='Shell weight', ylabel='Density'>

# %% [markdown]
# Observations: Shell weight has more than 1 mode.

# %% [markdown]
# Though the features are not normally distributed they are close to normality

# %% [markdown]
# Bivariate Analysis

# %%
sns.scatterplot(y='Sex',x='age', data = ab)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Sex'>

# %% [markdown]
# Observations:The infant ages are between 0-23.
#     The males have ages are between 3-26.
#     The females have close to 30 years representing that in this dataste they have the max age.

# %%
sns.scatterplot(y='Length',x='age', data = ab)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Length'>

# %% [markdown]
# Observation: As the length increases the age is also increasing. There is a positive corelation.
# There seems to be no outliers.

# %%
sns.scatterplot(y='Diameter', x='age', data = ab)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Diameter'>

# %% [markdown]
# Observation: As the diameter increases the ages are also increasing. There is a positive corelation.
# Possiblity of outliers is negligible.

# %%
sns.scatterplot(y='Height', x='age', data = ab)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Height'>

# %% [markdown]
# Observations: There seems to be 2 outliers here.

# %%
sns.scatterplot(y='Whole weight', x='age', data = ab)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Whole weight'>

# %% [markdown]
# Observations: When the age is 25 & 30 abalone has the maximum Whole Weight.

# %%
sns.scatterplot(y='Shucked weight', x='age', data = ab)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Shucked weight'>

# %% [markdown]
# Observation: The Maximum Shucked weight lies between 10-15 ages.

# %%
sns.scatterplot(y='Viscera weight', x='age', data = ab)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Viscera weight'>

# %% [markdown]
# Observation: The Maximum Viscera weight lies in 26 years.

# %%
sns.scatterplot(y='Shell weight', x='age', data = ab)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Shell weight'>

# %%
sns.pairplot(ab)

# %% [markdown]
# Observations: Many columns are positively correlated.

# %% [markdown]
# Encoding of categorical data

# %%
from sklearn.preprocessing import OrdinalEncoder

oe=OrdinalEncoder()

# %%
ab['Sex']=oe.fit_transform(ab['Sex'].values.reshape(-1,1))
ab
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0     2.0   0.455     0.365   0.095        0.5140          0.2245
# 1     2.0   0.350     0.265   0.090        0.2255          0.0995
# 2     0.0   0.530     0.420   0.135        0.6770          0.2565
# 3     2.0   0.440     0.365   0.125        0.5160          0.2155
# 4     1.0   0.330     0.255   0.080        0.2050          0.0895
# ...   ...     ...       ...     ...           ...             ...
# 4172  0.0   0.565     0.450   0.165        0.8870          0.3700
# 4173  2.0   0.590     0.440   0.135        0.9660          0.4390
# 4174  2.0   0.600     0.475   0.205        1.1760          0.5255
# 4175  0.0   0.625     0.485   0.150        1.0945          0.5310
# 4176  2.0   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight   age
# 0             0.1010        0.1500  16.5
# 1             0.0485        0.0700   8.5
# 2             0.1415        0.2100  10.5
# ...

# %%
ab.Sex.unique()
# Out:
# array([2., 0., 1.])

# %%
ab.describe()
# Out:
#                Sex       Length     Diameter       Height  Whole weight  \
# count  4177.000000  4177.000000  4177.000000  4177.000000   4177.000000
# mean      1.052909     0.523992     0.407881     0.139516      0.828742
# std       0.822240     0.120093     0.099240     0.041827      0.490389
# min       0.000000     0.075000     0.055000     0.000000      0.002000
# 25%       0.000000     0.450000     0.350000     0.115000      0.441500
# 50%       1.000000     0.545000     0.425000     0.140000      0.799500
# 75%       2.000000     0.615000     0.480000     0.165000      1.153000
# max       2.000000     0.815000     0.650000     1.130000      2.825500
#
#        Shucked weight  Viscera weight  Shell weight          age
# count     4177.000000     4177.000000   4177.000000  4177.000000
# mean         0.359367        0.180594      0.238831    11.433684
# std          0.221963        0.109614      0.139203     3.224169
# ...

# %% [markdown]
# Observations:
#
#              1.Coorelation can be ignored for categorical data Sex.
#              2.The mean & Median for all the independednt variables are close.
#              3.There could be outliers in Length,Height,Whole Weight,Shucked weight & Shell weight
#              columns.
#              4.The mean of Shucked weight (highly correlated with Traget) is 0.359367, SD =0.221963
#              25th percentile=0.186000,Median=0.336000 & 75th percentile=0.502000.The mean & median are
#              close.

# %%
ab.corr()
# Out:
#                      Sex    Length  Diameter    Height  Whole weight  \
# Sex             1.000000 -0.036066 -0.038874 -0.042077     -0.021391
# Length         -0.036066  1.000000  0.986812  0.827554      0.925261
# Diameter       -0.038874  0.986812  1.000000  0.833684      0.925452
# Height         -0.042077  0.827554  0.833684  1.000000      0.819221
# Whole weight   -0.021391  0.925261  0.925452  0.819221      1.000000
# Shucked weight -0.001373  0.897914  0.893162  0.774972      0.969405
# Viscera weight -0.032067  0.903018  0.899724  0.798319      0.966375
# Shell weight   -0.034854  0.897706  0.905330  0.817338      0.955355
# age            -0.034627  0.556720  0.574660  0.557467      0.540390
#
#                 Shucked weight  Viscera weight  Shell weight       age
# Sex                  -0.001373       -0.032067     -0.034854 -0.034627
# Length                0.897914        0.903018      0.897706  0.556720
# ...

# %%
sns.heatmap(ab.corr(),annot=True,linecolor='black')
# Out:
# <AxesSubplot:>

# %%
Observations:
    1.Length & Height are 56% correlated with Rings.
    2.Diameter is57% positively correalted with Rings.
    3.Whole weight is 54% correlated with Rings.
    4.Shucked weight is correlated by 42% with Rings.
    5.Viscera weight is 50% correlated with Rings.
    6.Shell weight has the highest positve corelation with Rings @63%.
    7. Maxmum Correlation is  shell weight & hte least correlated is Sex.

# %%
plt.figure(figsize=(22,7))
ab.corr()['age'].sort_values(ascending=False).drop(['age']).plot(kind='bar', color="m")
plt.xlabel("Feature",fontsize=14)
plt.ylabel('column with target names',fontsize=14)
plt.title('correlation',fontsize=18)
plt.show()

# %%
Observations:1. All the columns have positive correlation with the Traget column. 
             2.Sex is negatively correlation with the target.And so we can drop it.
             3.Shell Weight has the maximum correaltion with target.

# %%
#sorting in ascending order the correlation between target and other columns for easy undersatnding

ab.corr()['age'].sort_values()
# Out:
# Sex              -0.034627
# Shucked weight    0.420884
# Viscera weight    0.503819
# Whole weight      0.540390
# Length            0.556720
# Height            0.557467
# Diameter          0.574660
# Shell weight      0.627574
# age               1.000000
# Name: age, dtype: float64

# %% [markdown]
# Only sex column is negative but as its a categorical data we can ignore it. Most o fteh columns are close to +/-0.5 skewness. We will look individually for skewness in the data.

# %% [markdown]
# Checking for Outliers

# %%
ab.plot(kind="box",subplots =True,layout=(3,3))
# Out:
# Sex                  AxesSubplot(0.125,0.657941;0.227941x0.222059)
# Length            AxesSubplot(0.398529,0.657941;0.227941x0.222059)
# Diameter          AxesSubplot(0.672059,0.657941;0.227941x0.222059)
# Height               AxesSubplot(0.125,0.391471;0.227941x0.222059)
# Whole weight      AxesSubplot(0.398529,0.391471;0.227941x0.222059)
# Shucked weight    AxesSubplot(0.672059,0.391471;0.227941x0.222059)
# Viscera weight          AxesSubplot(0.125,0.125;0.227941x0.222059)
# Shell weight         AxesSubplot(0.398529,0.125;0.227941x0.222059)
# age                  AxesSubplot(0.672059,0.125;0.227941x0.222059)
# dtype: object

# %%
plt.boxplot(ab['Length'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x10ea081c430>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x10ea081cb50>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x10ea081c0a0>],
#  'medians': [<matplotlib.lines.Line2D at 0x10ea082a2b0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x10ea082a640>],
#  'means': []}

# %% [markdown]
# Observations: Outliers are present in Length column.

# %%
plt.boxplot(ab['Diameter'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x10ea0883a90>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x10ea08931f0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x10ea0883760>],
#  'medians': [<matplotlib.lines.Line2D at 0x10ea0893940>],
#  'fliers': [<matplotlib.lines.Line2D at 0x10ea0893cd0>],
#  'means': []}

# %%
plt.boxplot(ab['Height'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2711b99ce50>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2711b9ac5b0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2711b99cb20>],
#  'medians': [<matplotlib.lines.Line2D at 0x2711b9acd00>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2711b9b80d0>],
#  'means': []}

# %%
plt.boxplot(ab['Whole weight'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x10ea08f0430>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x10ea08f0b50>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x10ea08f00a0>],
#  'medians': [<matplotlib.lines.Line2D at 0x10ea08fb2b0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x10ea08fb640>],
#  'means': []}

# %%
plt.boxplot(ab['Viscera weight'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x10ea094bee0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x10ea095b640>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x10ea094bb50>],
#  'medians': [<matplotlib.lines.Line2D at 0x10ea095bd00>],
#  'fliers': [<matplotlib.lines.Line2D at 0x10ea09680d0>],
#  'means': []}

# %%
plt.boxplot(ab['Shell weight'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x10ea09c3520>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x10ea09c3c40>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x10ea09c3190>],
#  'medians': [<matplotlib.lines.Line2D at 0x10ea09cf3a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x10ea09cf730>],
#  'means': []}

# %%
plt.boxplot(ab['Shucked weight'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2711bb4c3a0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2711bb4cac0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2711bb3efd0>],
#  'medians': [<matplotlib.lines.Line2D at 0x2711bb5b220>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2711bb5b5b0>],
#  'means': []}

# %%
#dropping Sex column as no correlation with target.
ab=ab.drop(['Sex'],axis=1)
ab
# Out:
#       Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0      0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1      0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2      0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3      0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4      0.330     0.255   0.080        0.2050          0.0895          0.0395
# ...      ...       ...     ...           ...             ...             ...
# 4172   0.565     0.450   0.165        0.8870          0.3700          0.2390
# 4173   0.590     0.440   0.135        0.9660          0.4390          0.2145
# 4174   0.600     0.475   0.205        1.1760          0.5255          0.2875
# 4175   0.625     0.485   0.150        1.0945          0.5310          0.2610
# 4176   0.710     0.555   0.195        1.9485          0.9455          0.3765
#
#       Shell weight   age
# ...

# %%
ab.shape
# Out:
# (4177, 8)

# %% [markdown]
# Removing Outliers

# %%
from scipy.stats import zscore
z=np.abs(zscore(ab))
threshold = 3

# %%
ab_new=ab[(z<3).all(axis=1)]

# %%
ab_new
# Out:
#       Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0      0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1      0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2      0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3      0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4      0.330     0.255   0.080        0.2050          0.0895          0.0395
# ...      ...       ...     ...           ...             ...             ...
# 4172   0.565     0.450   0.165        0.8870          0.3700          0.2390
# 4173   0.590     0.440   0.135        0.9660          0.4390          0.2145
# 4174   0.600     0.475   0.205        1.1760          0.5255          0.2875
# 4175   0.625     0.485   0.150        1.0945          0.5310          0.2610
# 4176   0.710     0.555   0.195        1.9485          0.9455          0.3765
#
#       Shell weight   age
# ...

# %%
ab['age'].unique()
# Out:
# array([16.5,  8.5, 10.5, 11.5,  9.5, 21.5, 17.5, 20.5, 15.5, 12.5, 13.5,
#        19.5, 14.5,  6.5,  5.5,  7.5, 22.5, 18.5, 23.5,  2.5,  4.5, 27.5,
#        24.5, 30.5,  3.5, 28.5, 26.5, 25.5])

# %%
ab.age.value_counts()
# Out:
# 10.5    689
# 11.5    634
# 9.5     568
# 12.5    487
# 8.5     391
# 13.5    267
# 7.5     259
# 14.5    203
# 15.5    126
# 6.5     115
# 16.5    103
# 17.5     67
# 18.5     58
# 5.5      57
# 19.5     42
# 20.5     32
# 21.5     26
# 4.5      15
# 22.5     14
# 24.5      9
# 23.5      6
# 28.5      2
# 25.5      2
# 2.5       1
# 27.5      1
# 30.5      1
# 3.5       1
# 26.5      1
# Name: age, dtype: int64

# %%
len(np.where(z>3)[0])
# Out:
# 200

# %%
ab.shape
# Out:
# (4177, 8)

# %%
ab_new.shape
# Out:
# (4027, 8)

# %%
data_loss=(4177-4027)/4177*100
data_loss
# Out:
# 3.5910940866650707

# %% [markdown]
# As only 4% data had outliers I am dropping the same.

# %% [markdown]
# Using MinMax scaler for scaling the  numeric columns as they are of different units

# %%
from sklearn.preprocessing import MinMaxScaler
mns= MinMaxScaler()

# %%
ab_new[['Length','Diameter','Height','Whole weight','Shucked weight','Viscera weight','Shell weight']] = mns.fit_transform(ab_new[['Length','Diameter','Height','Whole weight','Shucked weight','Viscera weight','Shell weight']])

ab_new
# Out:
#         Length  Diameter    Height  Whole weight  Shucked weight  \
# 0     0.487395  0.510204  0.340426      0.224595        0.216510
# 1     0.310924  0.306122  0.319149      0.094874        0.092931
# 2     0.613445  0.622449  0.510638      0.297887        0.248146
# 3     0.462185  0.510204  0.468085      0.225495        0.207612
# 4     0.277311  0.285714  0.276596      0.085656        0.083045
# ...        ...       ...       ...           ...             ...
# 4172  0.672269  0.683673  0.638298      0.392311        0.360356
# 4173  0.714286  0.663265  0.510638      0.427833        0.428571
# 4174  0.731092  0.734694  0.808511      0.522257        0.514088
# 4175  0.773109  0.755102  0.574468      0.485612        0.519525
# 4176  0.915966  0.897959  0.765957      0.869604        0.929313
#
#       Viscera weight  Shell weight   age
# 0           0.204268      0.223077  16.5
# 1           0.097561      0.100000   8.5
# 2           0.286585      0.315385  10.5
# ...

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.model_selection import train_test_split

# %% [markdown]
# Splitting the data into x & y

# %%
x=ab_new.iloc[:,0:-1]
x
# Out:
#         Length  Diameter    Height  Whole weight  Shucked weight  \
# 0     0.487395  0.510204  0.340426      0.224595        0.216510
# 1     0.310924  0.306122  0.319149      0.094874        0.092931
# 2     0.613445  0.622449  0.510638      0.297887        0.248146
# 3     0.462185  0.510204  0.468085      0.225495        0.207612
# 4     0.277311  0.285714  0.276596      0.085656        0.083045
# ...        ...       ...       ...           ...             ...
# 4172  0.672269  0.683673  0.638298      0.392311        0.360356
# 4173  0.714286  0.663265  0.510638      0.427833        0.428571
# 4174  0.731092  0.734694  0.808511      0.522257        0.514088
# 4175  0.773109  0.755102  0.574468      0.485612        0.519525
# 4176  0.915966  0.897959  0.765957      0.869604        0.929313
#
#       Viscera weight  Shell weight
# 0           0.204268      0.223077
# 1           0.097561      0.100000
# 2           0.286585      0.315385
# 3           0.230691      0.230769
# ...

# %%
y=ab_new.iloc[:,-1]
y
# Out:
# 0       16.5
# 1        8.5
# 2       10.5
# 3       11.5
# 4        8.5
#         ...
# 4172    12.5
# 4173    11.5
# 4174    10.5
# 4175    11.5
# 4176    13.5
# Name: age, Length: 4027, dtype: float64

# %%
x.shape
# Out:
# (4027, 7)

# %%
y.shape
# Out:
# (4027,)

# %% [markdown]
# Splitting the data into Testing & Training

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30, random_state=45)

# %%
x_train.shape
# Out:
# (2818, 7)

# %%
x_test.shape
# Out:
# (1209, 7)

# %%
y_train.shape
# Out:
# (2818,)

# %%
y_test.shape
# Out:
# (1209,)

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([ -1.01019271,   4.88717331,   5.9292555 ,  15.75466022,
#        -17.47296837,  -3.24561663,   4.78542488])

# %%
lr.intercept_
# Out:
# 5.6853850846065175

# %%
lr.score(x_train,y_train)
# Out:
# 0.5036720178555165

# %%
x_preditc=lr.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.metrics import r2_score

# %%
print("Mean Absolute error:",mean_absolute_error(y_test,x_preditc))
print("Mean Squared error:", mean_squared_error(y_test,x_preditc))
print('Root Mean Squared error:',np.sqrt(mean_squared_error(y_test,x_preditc)))
print(r2_score(y_test,x_preditc))
# Out:
# Mean Absolute error: 1.5257116048394244
# Mean Squared error: 4.057509007340857
# Root Mean Squared error: 2.0143259436697076
# 0.5332948301284717

# %% [markdown]
# Checking for overfitting or underfitting of the data with lasso,ridge & elastic net

# %%
from sklearn.linear_model import Lasso,Ridge,ElasticNet

# %%
#Lasso Regulatisation Method
ls=Lasso(alpha=0.0001)
ls.fit(x_train,y_train)
print('score:',ls.score(x_train,y_train))
print("Mean Absolute error:",mean_absolute_error(y_test,x_preditc))
print("Mean Squared error:", mean_squared_error(y_test,x_preditc))
print('Root Mean Squared error:',np.sqrt(mean_squared_error(y_test,x_preditc)))
print('The coefficient values:',ls.coef_)
print('The intercept values are:',ls.intercept_)
print(r2_score(y_test,x_preditc))
# Out:
# score: 0.5036621900000551
# Mean Absolute error: 1.5257116048394244
# Mean Squared error: 4.057509007340857
# Root Mean Squared error: 2.0143259436697076
# The coefficient values: [ -0.83564077   4.71973905   5.91921582  15.45201505 -17.3384014
#   -3.15949799   4.87880552]
# The intercept values are: 5.683710204760196
# 0.5332948301284717

# %%
#Ridge Regulatisation Method
rg=Ridge(alpha=0.0001)
rg.fit(x_train,y_train)
print('Score:',rg.score(x_train,y_train))
print("Mean Absolute error:",mean_absolute_error(y_test,x_preditc))
print("Mean Squared error:", mean_squared_error(y_test,x_preditc))
print('Root Mean Squared error:',np.sqrt(mean_squared_error(y_test,x_preditc)))
print('The coefficient values:',rg.coef_)
print('The intercept values are:',rg.intercept_)
print(r2_score(y_test,x_preditc))
# Out:
# Score: 0.5036720176623846
# Mean Absolute error: 1.5257116048394244
# Mean Squared error: 4.057509007340857
# Root Mean Squared error: 2.0143259436697076
# The coefficient values: [ -1.01003952   4.88699888   5.9292565   15.75284836 -17.47207603
#   -3.24521905   4.78603442]
# The intercept values are: 5.68538164674322
# 0.5332948301284717

# %%
#ElasticNet Regulatisation Method
en=ElasticNet(alpha=0.0001)
en.fit(x_train,y_train)
print('Score:',en.score(x_train,y_train))
print("Mean Absolute error:",mean_absolute_error(y_test,x_preditc))
print("Mean Squared error:", mean_squared_error(y_test,x_preditc))
print('Root Mean Squared error:',np.sqrt(mean_squared_error(y_test,x_preditc)))
print('The coefficient values:',en.coef_)
print('The intercept values are:',en.intercept_)
print(r2_score(y_test,x_preditc))
# Out:
# Score: 0.5033413598763501
# Mean Absolute error: 1.5257116048394244
# Mean Squared error: 4.057509007340857
# Root Mean Squared error: 2.0143259436697076
# The coefficient values: [ -0.73294811   4.588201     5.92372377  13.42102042 -16.31372078
#   -2.72535494   5.55097732]
# The intercept values are: 5.681135854028111
# 0.5332948301284717

# %% [markdown]
# CV score of Linear Regression

# %%
from sklearn.model_selection import cross_val_score

# %% [markdown]
# Cross Validation score of Linear Regression

# %%
scr=cross_val_score(lr,x,y,cv=5)
print(scr)
print(scr.mean())
print(round(scr.std()),2)
# Out:
# [0.3932228  0.21334049 0.49661527 0.49987958 0.47055586]
# 0.41472280082211943
# 0 2

# %% [markdown]
# Cross Validation score of Lasso Regression

# %%
scr=cross_val_score(ls,x,y,cv=5)
print(scr)
print(scr.mean())
print(round(scr.std()),2)
# Out:
# [0.39207634 0.21370348 0.49669215 0.50032284 0.4708833 ]
# 0.41473562332789377
# 0 2

# %% [markdown]
# Cross Validation score of Ridge Regression

# %%
scr=cross_val_score(rg,x,y,cv=5)
print(scr)
print(scr.mean())
print(round(scr.std()),2)
# Out:
# [0.39321921 0.21334359 0.4966156  0.49988377 0.4705563 ]
# 0.4147236937227854
# 0 2

# %% [markdown]
# Cross Validation score of ElasticNet Regression

# %%
scr=cross_val_score(en,x,y,cv=5)
print(scr)
print(scr.mean())
print(round(scr.std()),2)
# Out:
# [0.38738457 0.21699132 0.49671902 0.50501812 0.47086375]
# 0.4153953560618128
# 0 2

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dt=DecisionTreeRegressor()

# %%
dt.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
dt.score(x_train,y_train)
# Out:
# 1.0

# %%
print("Mean Absolute error:",mean_absolute_error(y_test,x_preditc))
print("Mean Squared error:", mean_squared_error(y_test,x_preditc))
print('Root Mean Squared error:',np.sqrt(mean_squared_error(y_test,x_preditc)))
print(r2_score(y_test,x_preditc))
# Out:
# Mean Absolute error: 1.5257116048394244
# Mean Squared error: 4.057509007340857
# Root Mean Squared error: 2.0143259436697076
# 0.5332948301284717

# %%
a=np.array([0.350,0.265,0.090,0.2255,0.0995,0.0485,0.0700])
a
# Out:
# array([0.35  , 0.265 , 0.09  , 0.2255, 0.0995, 0.0485, 0.07  ])

# %%
a=a.reshape(1,-1)
a.shape
# Out:
# (1, 7)

# %%
dt.predict(a)
# Out:
# array([8.5])

# %%
df=pd.DataFrame(x_preditc)
df.to_csv('Abalone_Age_Prediction.csv')

# %%
Conclusion: We can use decision Tree Model as the accuracy score is 1.0
