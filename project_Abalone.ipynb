# %%
import pandas as pd
import numpy as np

# %%
ab=pd.read_csv("abaloneds.csv")
ab
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %%
ab.columns
# Out:
# Index(['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight',
#        'Viscera weight', 'Shell weight', 'Rings'],
#       dtype='object')

# %%
ab.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %%
ab.tail()
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12

# %%
ab.shape
# Out:
# (4177, 9)

# %%
#finding out the data types in each column
ab.dtypes
# Out:
# Sex                object
# Length            float64
# Diameter          float64
# Height            float64
# Whole weight      float64
# Shucked weight    float64
# Viscera weight    float64
# Shell weight      float64
# Rings               int64
# dtype: object

# %%
ab.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sex             4177 non-null   object
#  1   Length          4177 non-null   float64
#  2   Diameter        4177 non-null   float64
#  3   Height          4177 non-null   float64
#  4   Whole weight    4177 non-null   float64
#  5   Shucked weight  4177 non-null   float64
#  6   Viscera weight  4177 non-null   float64
#  7   Shell weight    4177 non-null   float64
#  8   Rings           4177 non-null   int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 293.8+ KB

# %%
ab.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %%
ab.drop_duplicates()
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %% [markdown]
# Observation:There are no duplicates in the dataset.

# %%
import seaborn as sns

# %%
sns.heatmap(ab.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# Observations: There is no null data in the Data set.

# %% [markdown]
# Visualisation of the Data Set

# %% [markdown]
# Categorical data visualisation

# %%
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
sns.countplot(x='Sex',data = ab)
print(ab['Sex'].value_counts())
# Out:
# M    1528
# I    1342
# F    1307
# Name: Sex, dtype: int64

# %% [markdown]
# Observations: The male count in this dataset is 1528, followed by Infants & females.

# %%
ab.skew()
# Out:
# Length           -0.639873
# Diameter         -0.609198
# Height            3.128817
# Whole weight      0.530959
# Shucked weight    0.719098
# Viscera weight    0.591852
# Shell weight      0.620927
# Rings             1.114102
# dtype: float64

# %%
sns.distplot(ab['Length'],kde=True)
# Out:
# <AxesSubplot:xlabel='Length', ylabel='Density'>

# %% [markdown]
# Observation: The length of abalone is slightly skewed to the left.

# %%
sns.distplot(ab['Diameter'], kde=True)
# Out:
# <AxesSubplot:xlabel='Diameter', ylabel='Density'>

# %% [markdown]
# Observation: The diameter of abalone is slightly skewed to the left.

# %%
sns.distplot(ab['Height'], kde=True)
# Out:
# <AxesSubplot:xlabel='Height', ylabel='Density'>

# %% [markdown]
# Observations: This is falling under the normal distribution.

# %%
sns.distplot(ab['Whole weight'], kde=True)
# Out:
# <AxesSubplot:xlabel='Whole weight', ylabel='Density'>

# %% [markdown]
# Observation: The whole weight column is slightly skewed to the right.

# %%
sns.distplot(ab['Shucked weight'], kde=True)
# Out:
# <AxesSubplot:xlabel='Shucked weight', ylabel='Density'>

# %% [markdown]
# Observations: Shucked weight is not falling under the normal distribution.

# %%
sns.distplot(ab['Viscera weight'], kde=True)
# Out:
# <AxesSubplot:xlabel='Viscera weight', ylabel='Density'>

# %% [markdown]
# Observations: Shucked weight is not falling under the normal distribution.

# %%
sns.distplot(ab['Shell weight'], kde=True)
# Out:
# <AxesSubplot:xlabel='Shell weight', ylabel='Density'>

# %% [markdown]
# Observations: Shell weight has more than 1 mode.

# %% [markdown]
# Bivariate Analysis

# %%
sns.scatterplot(y='Sex',x='Rings', data = ab)
# Out:
# <AxesSubplot:xlabel='Rings', ylabel='Sex'>

# %% [markdown]
# Observations:The infant rings are between 0-20.
#     The males have rings between 3-26.
#     The females have close to 30 rings showing that they have the max age.

# %%
sns.scatterplot(y='Length',x='Rings', data = ab)
# Out:
# <AxesSubplot:xlabel='Rings', ylabel='Length'>

# %% [markdown]
# Observation: As the length increases the rings are also increasing. There is a positive corelation.

# %%
sns.scatterplot(y='Diameter', x='Rings', data = ab)
# Out:
# <AxesSubplot:xlabel='Rings', ylabel='Diameter'>

# %% [markdown]
# Observation: As the diameter increases the rings are also increasing. There is a positive corelation.

# %%
sns.barplot(y='Height', x='Rings', data = ab)
# Out:
# <AxesSubplot:xlabel='Rings', ylabel='Height'>

# %% [markdown]
# Observations: The maximum Height has also the maximum rings.

# %%
sns.barplot(y='Whole weight', x='Rings', data = ab)
# Out:
# <AxesSubplot:xlabel='Rings', ylabel='Whole weight'>

# %% [markdown]
# Observations: The maximum Whole Weight also has the maximum rings.

# %%
ab.columns
# Out:
# Index(['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight',
#        'Viscera weight', 'Shell weight', 'Rings'],
#       dtype='object')

# %%
sns.scatterplot(y='Shucked weight', x='Rings', data = ab)
# Out:
# <AxesSubplot:xlabel='Rings', ylabel='Shucked weight'>

# %% [markdown]
# Observation: The Maximum Shucked weight lies between 10-13 rings.

# %%
sns.barplot(y='Viscera weight', x='Rings', data = ab)
# Out:
# <AxesSubplot:xlabel='Rings', ylabel='Viscera weight'>

# %% [markdown]
# Observation: The Maximum Viscera weight lies in 24 rings.

# %% [markdown]
# sns.barplot(y='Shell weight', x='Rings', data = ab)

# %% [markdown]
# Observations:Shell weight is maximum for 27 rings.

# %%
sns.pairplot(ab)

# %%
Observations: Length & Diameter are having a positive correlation.

# %% [markdown]
# Encoding of categorical data

# %%
from sklearn.preprocessing import OrdinalEncoder

oe=OrdinalEncoder()

# %%
ab['Sex']=oe.fit_transform(ab['Sex'].values.reshape(-1,1))
ab
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0     2.0   0.455     0.365   0.095        0.5140          0.2245
# 1     2.0   0.350     0.265   0.090        0.2255          0.0995
# 2     0.0   0.530     0.420   0.135        0.6770          0.2565
# 3     2.0   0.440     0.365   0.125        0.5160          0.2155
# 4     1.0   0.330     0.255   0.080        0.2050          0.0895
# ...   ...     ...       ...     ...           ...             ...
# 4172  0.0   0.565     0.450   0.165        0.8870          0.3700
# 4173  2.0   0.590     0.440   0.135        0.9660          0.4390
# 4174  2.0   0.600     0.475   0.205        1.1760          0.5255
# 4175  0.0   0.625     0.485   0.150        1.0945          0.5310
# 4176  2.0   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %%
ab.Sex.unique()
# Out:
# array([2., 0., 1.])

# %%
ab.describe()
# Out:
#                Sex       Length     Diameter       Height  Whole weight  \
# count  4177.000000  4177.000000  4177.000000  4177.000000   4177.000000
# mean      1.052909     0.523992     0.407881     0.139516      0.828742
# std       0.822240     0.120093     0.099240     0.041827      0.490389
# min       0.000000     0.075000     0.055000     0.000000      0.002000
# 25%       0.000000     0.450000     0.350000     0.115000      0.441500
# 50%       1.000000     0.545000     0.425000     0.140000      0.799500
# 75%       2.000000     0.615000     0.480000     0.165000      1.153000
# max       2.000000     0.815000     0.650000     1.130000      2.825500
#
#        Shucked weight  Viscera weight  Shell weight        Rings
# count     4177.000000     4177.000000   4177.000000  4177.000000
# mean         0.359367        0.180594      0.238831     9.933684
# std          0.221963        0.109614      0.139203     3.224169
# ...

# %% [markdown]
# Observations:
#
#              1.Coorelation can be ignored for categorical data Sex.
#              2.The mean & Median for all the independednt variables are close.
#              3.There could be outliers in Length,Height,Whole Weight,Shucked weight & Shell weight
#              columns.
#              4.The mean of Shucked weight (highly correlated with Traget) is 0.359367, SD =0.221963
#              25th percentile=0.186000,Median=0.336000 & 75th percentile=0.502000.The mean & median are
#              close.

# %%
ab.corr()
# Out:
#                      Sex    Length  Diameter    Height  Whole weight  \
# Sex             1.000000 -0.036066 -0.038874 -0.042077     -0.021391
# Length         -0.036066  1.000000  0.986812  0.827554      0.925261
# Diameter       -0.038874  0.986812  1.000000  0.833684      0.925452
# Height         -0.042077  0.827554  0.833684  1.000000      0.819221
# Whole weight   -0.021391  0.925261  0.925452  0.819221      1.000000
# Shucked weight -0.001373  0.897914  0.893162  0.774972      0.969405
# Viscera weight -0.032067  0.903018  0.899724  0.798319      0.966375
# Shell weight   -0.034854  0.897706  0.905330  0.817338      0.955355
# Rings          -0.034627  0.556720  0.574660  0.557467      0.540390
#
#                 Shucked weight  Viscera weight  Shell weight     Rings
# Sex                  -0.001373       -0.032067     -0.034854 -0.034627
# Length                0.897914        0.903018      0.897706  0.556720
# ...

# %%
sns.heatmap(ab.corr(),annot=True,linecolor='black')
# Out:
# <AxesSubplot:>

# %%
Observations:
    1.Length & Height are 56% correlated with Rings.
    2.Diameter is57% positively correalted with Rings.
    3.Whole weight is 54% correlated with Rings.
    4.Shucked weight is correlated by 42% with Rings.
    5.Viscera weight is 50% correlated with Rings.
    6.Shell weight has the highest positve corelation with Rings @63%.
    7. Maxmum Correlation is  shell weight & hte least correlated is Sex.

# %%
plt.figure(figsize=(22,7))
ab.corr()['Rings'].sort_values(ascending=False).drop(['Rings']).plot(kind='bar', color="m")
plt.xlabel("Feature",fontsize=14)
plt.ylabel('column with target names',fontsize=14)
plt.title('correlation',fontsize=18)
plt.show()

# %%
Observations:1. All the columns have positive correlation with the Traget column. 
             2.Sex has the least correlation with the target.And so we can drop it.
             3.Shell Weight has the maximum correaltion with target.

# %%
#sorting in ascending order the correlation between target and other columns for easy undersatnding

ab.corr()['Rings'].sort_values()
# Out:
# Sex              -0.034627
# Shucked weight    0.420884
# Viscera weight    0.503819
# Whole weight      0.540390
# Length            0.556720
# Height            0.557467
# Diameter          0.574660
# Shell weight      0.627574
# Rings             1.000000
# Name: Rings, dtype: float64

# %% [markdown]
# Checking skewnes:

# %% [markdown]
# Checking for Outliers

# %%
ab.plot(kind="box",subplots =True,layout=(3,3))
# Out:
# Sex                  AxesSubplot(0.125,0.657941;0.227941x0.222059)
# Length            AxesSubplot(0.398529,0.657941;0.227941x0.222059)
# Diameter          AxesSubplot(0.672059,0.657941;0.227941x0.222059)
# Height               AxesSubplot(0.125,0.391471;0.227941x0.222059)
# Whole weight      AxesSubplot(0.398529,0.391471;0.227941x0.222059)
# Shucked weight    AxesSubplot(0.672059,0.391471;0.227941x0.222059)
# Viscera weight          AxesSubplot(0.125,0.125;0.227941x0.222059)
# Shell weight         AxesSubplot(0.398529,0.125;0.227941x0.222059)
# Rings                AxesSubplot(0.672059,0.125;0.227941x0.222059)
# dtype: object

# %%
plt.boxplot(ab['Length'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f1ec41b730>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1f1ec41be50>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1f1ec41b3a0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f1ec4265b0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f1ec426940>],
#  'means': []}

# %% [markdown]
# Observations: Outliers are present in Length column.

# %%
plt.boxplot(ab['Diameter'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1745b064b80>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1745b0752e0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1745b0647f0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1745b075a00>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1745b075d90>],
#  'means': []}

# %%
plt.boxplot(ab['Height'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1745b0d35e0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1745b0d3d00>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1745b0d3250>],
#  'medians': [<matplotlib.lines.Line2D at 0x1745b0de460>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1745b0de7f0>],
#  'means': []}

# %%
plt.boxplot(ab['Whole weight'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1745b13e040>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1745b13e760>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1745b131c70>],
#  'medians': [<matplotlib.lines.Line2D at 0x1745b13ee80>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1745b14a250>],
#  'means': []}

# %%
plt.boxplot(ab['Viscera weight'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1745a99c1f0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1745a950970>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1745a99cbe0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1745a950a60>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1745a950640>],
#  'means': []}

# %%
plt.boxplot(ab['Shell weight'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1745a961430>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1745a961b50>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1745a9610a0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1745a9442b0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1745a944640>],
#  'means': []}

# %%
plt.boxplot(ab['Shucked weight'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1745ad27e80>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1745ad345e0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1745ad27af0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1745ad34d00>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1745ad3e0d0>],
#  'means': []}

# %%
#dropping Sex column as no correlation with target.
ab=ab.drop(['Sex'],axis=1)
ab
# Out:
#       Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0      0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1      0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2      0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3      0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4      0.330     0.255   0.080        0.2050          0.0895          0.0395
# ...      ...       ...     ...           ...             ...             ...
# 4172   0.565     0.450   0.165        0.8870          0.3700          0.2390
# 4173   0.590     0.440   0.135        0.9660          0.4390          0.2145
# 4174   0.600     0.475   0.205        1.1760          0.5255          0.2875
# 4175   0.625     0.485   0.150        1.0945          0.5310          0.2610
# 4176   0.710     0.555   0.195        1.9485          0.9455          0.3765
#
#       Shell weight  Rings
# ...

# %%
ab.shape
# Out:
# (4177, 8)

# %% [markdown]
# Removing Outliers

# %%
from scipy.stats import zscore
z=np.abs(zscore(ab))
threshold = 3

# %% [markdown]
# IQR method

# %%
q1=ab.quantile(0.25)
q1
# Out:
# Length            0.4500
# Diameter          0.3500
# Height            0.1150
# Whole weight      0.4415
# Shucked weight    0.1860
# Viscera weight    0.0935
# Shell weight      0.1300
# Rings             8.0000
# Name: 0.25, dtype: float64

# %%
q3=ab.quantile(0.75)
q3
# Out:
# Length             0.615
# Diameter           0.480
# Height             0.165
# Whole weight       1.153
# Shucked weight     0.502
# Viscera weight     0.253
# Shell weight       0.329
# Rings             11.000
# Name: 0.75, dtype: float64

# %%
IQR=q3-q1

# %%
IQR
# Out:
# Length            0.1650
# Diameter          0.1300
# Height            0.0500
# Whole weight      0.7115
# Shucked weight    0.3160
# Viscera weight    0.1595
# Shell weight      0.1990
# Rings             3.0000
# dtype: float64

# %%
Lower_fence=q1-(1.5*IQR)
Lower_fence
# Out:
# Length            0.20250
# Diameter          0.15500
# Height            0.04000
# Whole weight     -0.62575
# Shucked weight   -0.28800
# Viscera weight   -0.14575
# Shell weight     -0.16850
# Rings             3.50000
# dtype: float64

# %%
Higher_fence=q3+(1.5*IQR)
Higher_fence
# Out:
# Length             0.86250
# Diameter           0.67500
# Height             0.24000
# Whole weight       2.22025
# Shucked weight     0.97600
# Viscera weight     0.49225
# Shell weight       0.62750
# Rings             15.50000
# dtype: float64

# %%
ab_new=ab[(z<3).all(axis=1)]

# %%
ab_new
# Out:
#       Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0      0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1      0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2      0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3      0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4      0.330     0.255   0.080        0.2050          0.0895          0.0395
# ...      ...       ...     ...           ...             ...             ...
# 4172   0.565     0.450   0.165        0.8870          0.3700          0.2390
# 4173   0.590     0.440   0.135        0.9660          0.4390          0.2145
# 4174   0.600     0.475   0.205        1.1760          0.5255          0.2875
# 4175   0.625     0.485   0.150        1.0945          0.5310          0.2610
# 4176   0.710     0.555   0.195        1.9485          0.9455          0.3765
#
#       Shell weight  Rings
# ...

# %%
ab.shape
# Out:
# (4177, 8)

# %%
ab_new.shape
# Out:
# (4027, 8)

# %% [markdown]
# As only 3% data had outliers I am dropping the same.

# %% [markdown]
# Using MinMax scaler for scaling the  numeric columns as they are of different units

# %%
from sklearn.preprocessing import MinMaxScaler
mns= MinMaxScaler()

# %%
ab_new[['Length','Diameter','Height','Whole weight','Shucked weight','Viscera weight','Shell weight']] = mns.fit_transform(ab_new[['Length','Diameter','Height','Whole weight','Shucked weight','Viscera weight','Shell weight']])

ab_new
# Out:
#         Length  Diameter    Height  Whole weight  Shucked weight  \
# 0     0.487395  0.510204  0.340426      0.224595        0.216510
# 1     0.310924  0.306122  0.319149      0.094874        0.092931
# 2     0.613445  0.622449  0.510638      0.297887        0.248146
# 3     0.462185  0.510204  0.468085      0.225495        0.207612
# 4     0.277311  0.285714  0.276596      0.085656        0.083045
# ...        ...       ...       ...           ...             ...
# 4172  0.672269  0.683673  0.638298      0.392311        0.360356
# 4173  0.714286  0.663265  0.510638      0.427833        0.428571
# 4174  0.731092  0.734694  0.808511      0.522257        0.514088
# 4175  0.773109  0.755102  0.574468      0.485612        0.519525
# 4176  0.915966  0.897959  0.765957      0.869604        0.929313
#
#       Viscera weight  Shell weight  Rings
# 0           0.204268      0.223077     15
# 1           0.097561      0.100000      7
# 2           0.286585      0.315385      9
# ...

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.model_selection import train_test_split

# %% [markdown]
# Splitting the data into x & y

# %%
x=ab_new.iloc[:,0:-1]
x
# Out:
#         Length  Diameter    Height  Whole weight  Shucked weight  \
# 0     0.487395  0.510204  0.340426      0.224595        0.216510
# 1     0.310924  0.306122  0.319149      0.094874        0.092931
# 2     0.613445  0.622449  0.510638      0.297887        0.248146
# 3     0.462185  0.510204  0.468085      0.225495        0.207612
# 4     0.277311  0.285714  0.276596      0.085656        0.083045
# ...        ...       ...       ...           ...             ...
# 4172  0.672269  0.683673  0.638298      0.392311        0.360356
# 4173  0.714286  0.663265  0.510638      0.427833        0.428571
# 4174  0.731092  0.734694  0.808511      0.522257        0.514088
# 4175  0.773109  0.755102  0.574468      0.485612        0.519525
# 4176  0.915966  0.897959  0.765957      0.869604        0.929313
#
#       Viscera weight  Shell weight
# 0           0.204268      0.223077
# 1           0.097561      0.100000
# 2           0.286585      0.315385
# 3           0.230691      0.230769
# ...

# %%
y=ab_new.iloc[:,-1]
y
# Out:
# 0       15
# 1        7
# 2        9
# 3       10
# 4        7
#         ..
# 4172    11
# 4173    10
# 4174     9
# 4175    10
# 4176    12
# Name: Rings, Length: 4027, dtype: int64

# %%
x.shape
# Out:
# (4027, 7)

# %%
y.shape
# Out:
# (4027,)

# %% [markdown]
# Splitting the data into Testing & Training

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30, random_state=45)

# %%
x_train.shape
# Out:
# (2818, 7)

# %%
x_test.shape
# Out:
# (1209, 7)

# %%
y_train.shape
# Out:
# (2818,)

# %%
y_test.shape
# Out:
# (1209,)

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([ -1.01019271,   4.88717331,   5.9292555 ,  15.75466022,
#        -17.47296837,  -3.24561663,   4.78542488])

# %%
lr.intercept_
# Out:
# 4.1853850846065175

# %%
lr.score(x_train,y_train)
# Out:
# 0.5036720178555165

# %%
x_preditc=lr.predict(x_test)

# %%
print("The predicted result of Rings:", x_predict)
print('Actual Ring:', y_test)
# Out:
# The predicted result of Rings: [ 8.9224517   9.90620652  5.80292526 ...  9.45998679  9.02094901
#  11.61262763]
# Actual Ring: 3847     9
# 3824     7
# 2713     4
# 804     10
# 429     18
#         ..
# 2251    13
# 910      5
# 2061     8
# 877     10
# 3415     9
# Name: Rings, Length: 1209, dtype: int64

# %%
print('error:')
print("Mean Absolute error:",mean_absolute_error(y_test,x_predict))
print("Mean squared error:",mean_squared_error(y_test,x_predict))

print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test,x_predict)))
# Out:
# error:
# Mean Absolute error: 1.5257116048394244
# Mean squared error: 4.057509007340858
# Root Mean Squared Error: 2.0143259436697076

# %%
from sklearn.metrics import r2_score
print(r2_score(y_test,x_predict))
# Out:
# 0.5332948301284715

# %% [markdown]
# Regularisation Technique to check teh bias-variance in the data

# %%
from sklearn.linear_model import Lasso,Ridge,ElasticNet

# %%
#Lasso Regulatisation Method
ls=Lasso(alpha=0.0001)
ls.fit(x_train,y_train)
ls.score(x_train,y_train)
# Out:
# 0.5036621900000551
